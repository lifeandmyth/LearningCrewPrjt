# %% [markdown]
# ## 1. 먼저 news_text_sm의 데이터를 읽어오자

# %%
import pandas as pd
import numpy as np

# konlpy 호출
from konlpy.tag import Okt

# 자연어, 불용어 처리 및 wordcloud 생성을 위해
# 집계 메소드
from collections import Counter
from konlpy.tag import Komoran
# https://datascienceschool.net/03%20machine%20learning/03.01.01%20NLTK%20%EC%9E%90%EC%97%B0%EC%96%B4%20%EC%B2%98%EB%A6%AC%20%ED%8C%A8%ED%82%A4%EC%A7%80.html
from nltk.tokenize import word_tokenize

# %%
# 먼저 news_text_sm 컬럼의 값들을 뭉쳐서 하나의 string(각 요소는 '\n'로 나누기)
# 으로 통합
import csv # total_news_t에서 갖고 오기

f = open("../know_arc_pjt/data_crawling_D/data_sql_total_edited/total_news_t_202306221233.csv", "r", encoding='utf8')
reader = csv.reader(f)

for row in reader:
    data = list(reader)
# print(data)
f.close()

# %%
# dataframe으로 만들기
df_total = pd.DataFrame(data=data, columns=['news_date', 'news_title', 'news_text_sm', 'url_in', 'news_writer', 'tags_string', 'thumb_addr', 'news_site'])  
df_total
# Out:
#         news_date                                     news_title  \
# 0     2023.05.31.                대시보드로 보는 모니터링의 미래, '풀스택 옵저버빌리티'
# 1     2023.05.31.                      티오베 선정 ‘올해의 프로그래밍 언어’의 비밀
# 2      2023.05.31          글로벌 칼럼 | 맥이 비즈니스 환경에서 윈도우의 그늘을 벗어난 방법
# 3      2023.05.31                         IT 직원이 회사를 떠나는 12가지 이유
# 4      2023.05.31  엔비디아, 반도체기업 최초 시총 1조 달러 “AI 전쟁터의 유일한 무기 판매업체”
# ...           ...                                            ...
# 6652   1000.10.10                                              0
# 6653   1000.10.10                                              0
# 6654   1000.10.10                                              0
# 6655   1000.10.10                                              0
# 6656   1000.10.10                                              0
#
#                                            news_text_sm  \
# 0     IT 성능 관리를 위해 도입하던 ‘모니터링’이 한계에 달했다는 평가와 더불어, ‘옵...
# 1     좋은 프로그래밍 언어는 어떻게 정의할 수 있을까요? 상황에 따라 중요도는 다르겠지만...
# 2     2006년 1월, 애플은 비즈니스 세계에서 성공을 향한 중요한 발걸음을 내디뎠다. ...
# 3     IT 인력에 대한 수요가 증가한다. 인력 시장이 여전히 경색되어 있다. CIO로서는...
# 4     AI와 관련한 핵심 투자처를 물색하던 투자자들이 기반을 찾은 것으로 보인다. 30일...
# ...                                                 ...
# 6652
# 6653
# 6654
# 6655
# 6656
#
#                                                  url_in      news_writer  \
# 0        https://yozm.wishket.com/magazine/detail/2047/              조은정
# 1        https://yozm.wishket.com/magazine/detail/2046/              애옹킴
# 2     https://www.itworld.co.kr/t/55049/%EA%B8%80%EB...  Anirban Ghoshal
# 3     https://www.itworld.co.kr/t/55049/%EA%B8%80%EB...       Paul Krill
# 4     https://www.itworld.co.kr/t/55049/%EA%B8%80%EB...    Neal Weinberg
# ...                                                 ...              ...
# 6652                                                  0                0
# 6653                                                  0                0
# 6654                                                  0                0
# 6655                                                  0                0
# 6656                                                  0                0
#
#      tags_string                                         thumb_addr news_site
# 0                  https://yozm.wishket.com/media/news/2047/imag...      요즘IT
# 1                 https://yozm.wishket.com/media/news/2046/image...      요즘IT
# 2                 https://www.itworld.co.kr/files/itworld/ITW202...   ITWorld
# 3                 https://www.itworld.co.kr/files/ciokr/2023/05/...   ITWorld
# 4                 https://www.itworld.co.kr/files/itworld/ITW202...   ITWorld
# ...          ...                                                ...       ...
# 6652           0                                                          CWN
# 6653           0                                                          CWN
# 6654           0                                                          CWN
# 6655           0                                                          CWN
# 6656           0                                                          CWN
#
# [6657 rows x 8 columns]

# %%
df_total_date_n_text = df_total[['news_date', 'news_text_sm']]
# csv 파일로 저장하기
df_total_date_n_text.to_csv("../know_arc_pjt/test_data/total_date_n_text.txt", mode='a', header=False, index=False, sep='\t')

# %%
# df_cwn_date = df_cwn['news_date'].to_list()
# df_cwn_text = df_cwn['news_text_sm'].to_list()
# df_cwn_date_n_text = {}
# for date, text in zip(df_cwn_date, df_cwn_text):
#     df_cwn_date_n_text[date] = text
                          
# print('dict zip : ', df_cwn_date_n_text)

# df_cwn_text

# %%
df_total_date_n_text
# Out:
#         news_date                                       news_text_sm
# 0     2023.05.31.  IT 성능 관리를 위해 도입하던 ‘모니터링’이 한계에 달했다는 평가와 더불어, ‘옵...
# 1     2023.05.31.  좋은 프로그래밍 언어는 어떻게 정의할 수 있을까요? 상황에 따라 중요도는 다르겠지만...
# 2      2023.05.31  2006년 1월, 애플은 비즈니스 세계에서 성공을 향한 중요한 발걸음을 내디뎠다. ...
# 3      2023.05.31  IT 인력에 대한 수요가 증가한다. 인력 시장이 여전히 경색되어 있다. CIO로서는...
# 4      2023.05.31  AI와 관련한 핵심 투자처를 물색하던 투자자들이 기반을 찾은 것으로 보인다. 30일...
# ...           ...                                                ...
# 6652   1000.10.10
# 6653   1000.10.10
# 6654   1000.10.10
# 6655   1000.10.10
# 6656   1000.10.10
#
# [6657 rows x 2 columns]

# %%
# f = open("../know_arc_pjt/data_crawling_D/data_sql_total_edited/total_news_t_202306221233.csv", "r", encoding='utf8')
# reader = csv.reader(f)

# for row in reader:
#     data = list(reader)
# # print(data)
# f.close()
# # dataframe으로 만들기
# df_total_t = pd.DataFrame(data=data, columns=['news_date', 'news_title', 'news_text_sm', 'url_in', 'news_writer', 'tags_string', 'thumb_addr', 'news_site'])  
# df_total_t

# %%
def get_date_text(fname):
    # 튜토리얼에서 이용하는 `fname` 파일은 영화평과 평점이 \t 으로 구분된 two column tsv 파일입니다.
    # 예시는 이 cell 의 output 을 참고하세요.
    with open(fname, encoding='utf-8') as f:
        docs = [doc.lower().replace('\n','').split('\t') for doc in f] 
        docs = [doc for doc in docs if len(doc) == 2]

        if not docs:
            return [], []
        
        dates, texts = zip(*docs)
        return list(dates), list(texts)

# cwn.kr data (df_cwn_date_n_text)
fname = '../know_arc_pjt/test_data/total_date_n_text.txt'
# 이걸로 
dates, texts = get_date_text(fname)

# 위쪽의 5개 출력하기
# with open(fname, encoding="utf-8") as f:
#     for _ in range(5):
#         print(next(f).strip())

# %%
# dates
# texts

# %%
# KR-WordRank에 필요한 라이브러리
import sys
sys.path.append('../')
from krwordrank.word import KRWordRank
from krwordrank.hangle import normalize
import krwordrank
# print(krwordrank.__version__)

# %% [markdown]
# 단어 추출에 영어/숫자를 포함할 예정이라면 normalize함수를 이용하여 텍스트를 normalize할 것

# %%
# with open('../know_arc_pjt/test_data/total_date_n_text_norm.txt', 'w', encoding='utf-8') as f:
#     for date, text in zip(dates, texts):
#         text = normalize(text, english=True, number=True)
#         f.write('%s\t%s\n' % (date, text))

# 주석 처리한 이유 : 쓸데없이 키워드 목록에 숫자나 의미없는 영문자들이 출몰함

# %% [markdown]
# ## 해당 데이터에서 핵심 키워드들을 뽑아보자

# %%
# df_cwn_date_n_text
fname = '../know_arc_pjt/test_data/total_date_n_text.txt'
dates_n, texts_n = get_date_text(fname)

# %%
wordrank_extractor = KRWordRank(
    min_count = 5, # 단어의 최소 출현 빈도수 (그래프 생성 시)
    max_length = 10, # 단어의 최대 길이
    verbose = True
    )

beta = 0.85    # PageRank의 decaying factor beta
max_iter = 20

keywords, rank, graph = wordrank_extractor.extract(texts, beta, max_iter)
# Out:
# scan vocabs ...
# num vocabs = 572006
# done = 12 Early stopped.

# %% [markdown]
# 위와 같이 vocabulary를 미리 설정하거나 decaying factor를 단어별로 다르게 (bias) 할당할 수 있으며, 모든 단어의 랭킹의 총 합은 vocabulary size와 같음. 즉 default decaying factor는 1.0
#
# 불용어도 같이 처리합니다.

# %%
# keywords
# Out:
# dict

# %%
# 불용어 파일 읽기
stop_words = []
with open('../know_arc_pjt/data_crawling_D/불용.txt', 'r', encoding='utf-8') as file:
   stop_words = file.read().splitlines()
# keyword_list
# # 불용어 제거
pop_list = []
for keyword in keywords:
    # print(keyword)
    # print(type(keyword))
    if keyword in stop_words:
        pop_list.append(keyword)
        # print(keyword)
        
# print(pop_list)
for p in pop_list:
    # print(p)
    keywords.pop(p, None)

# # filtered_tokens =  [token for token in keyword_list[0] if token not in stop_words]
# # filtered_tokens
# keywords

# %%
top_keywords = []
# for word, r in sorted(keywords.items(), key=lambda x:x[1], reverse=True)[:30]:
#     print('%8s:\t%.4f' % (word, r))
top_keywords.append(
    sorted(keywords.items(),
           key=lambda x:x[1],
           reverse=True)[:100]
)


keyword_list = []
for keywords in top_keywords:
    words, ranks = zip(*keywords)
    print(words)
    
    keyword_list.append(words)
# Out:
# ('기업', '개발', 'ai', '데이터', '플랫폼', '서비스', '언어', '보안', '디지털', '솔루션', '글로벌', '시장', '전문', '사업', '국내', '구글', '클라', '관리', '시스템', '코딩', '코드', '연구', '제품', '올해', 'nft', '공식', '애플', '정보', '테크', '교육', '분야', '매체', '운영', '스마트', '메타', '고객', 'it', '투자', '산업', '사이버', '학습', '구축', '통합', '인공', '소프트', '로봇', '한국', '온라인', '모델', '검색', '게임', '콘텐츠', '자동', '가상', '스타트업', '업무', '설명', '기준', '비즈니스', '것을', '오픈', '환경', '티오베', '파이썬', '업계', '전월', '과정', '5g', '계획', '공격', 'and', '확장', '컴퓨터', '모바일', '필요', '혁신', '자바', '영상', 'in', 'for', '마이', '매우', 'co', '기관', '일부', '포함', '서울', 'programming', '설계', '지역', '공급', '암호화', '개인', '직접', '시작', '네이버', '인프라', '테스트', '기록', '자사')

# %%
for k in range(100):
    
    message = '  --  '.join(
        ['%8s (%.3f)' % (top_keywords[0][k][0],top_keywords[0][k][1])]
         )
    print(message)
# Out:
#       기업 (628.627)
#       개발 (572.606)
#       ai (563.816)
#      데이터 (517.602)
#      플랫폼 (460.489)
#      서비스 (458.896)
#       언어 (446.975)
#       보안 (340.452)
#      디지털 (309.387)
#      솔루션 (275.015)
#      글로벌 (231.717)
#       시장 (216.945)
#       전문 (215.803)
#       사업 (186.116)
#       국내 (181.515)
#       구글 (175.531)
#       클라 (175.247)
#       관리 (173.423)
#      시스템 (169.183)
#       코딩 (168.011)
#       코드 (164.435)
#       연구 (160.767)
#       제품 (159.339)
#       올해 (157.634)
#      nft (157.299)
#       공식 (156.745)
#       애플 (152.281)
#       정보 (148.286)
#       테크 (148.265)
#       교육 (148.141)
#       분야 (147.730)
#       매체 (146.812)
#       운영 (144.585)
#      스마트 (142.526)
#       메타 (141.201)
#       고객 (140.780)
#       it (140.608)
#       투자 (134.902)
#       산업 (132.433)
#      사이버 (128.555)
#       학습 (127.476)
#       구축 (126.449)
#       통합 (125.387)
#       인공 (125.341)
#      소프트 (124.362)
#       로봇 (122.030)
#       한국 (120.657)
#      온라인 (118.995)
#       모델 (118.138)
#       검색 (117.174)
#       게임 (114.669)
#      콘텐츠 (113.201)
#       자동 (112.390)
#       가상 (111.479)
#     스타트업 (111.158)
#       업무 (109.036)
#       설명 (108.359)
#       기준 (107.045)
#     비즈니스 (103.065)
#       것을 (102.765)
#       오픈 (100.484)
#       환경 (98.338)
#      티오베 (92.458)
#      파이썬 (90.878)
#       업계 (90.799)
#       전월 (88.173)
#       과정 (87.832)
#       5g (87.390)
#       계획 (86.108)
#       공격 (85.977)
#      and (85.600)
#       확장 (85.068)
#      컴퓨터 (84.349)
#      모바일 (84.068)
#       필요 (83.835)
#       혁신 (83.739)
#       자바 (83.705)
#       영상 (82.455)
#       in (81.498)
#      for (81.272)
#       마이 (80.982)
#       매우 (80.429)
#       co (79.175)
#       기관 (79.056)
#       일부 (78.664)
#       포함 (77.770)
#       서울 (77.095)
# programming (76.976)
#       설계 (76.471)
#       지역 (76.425)
#       공급 (76.371)
#      암호화 (76.232)
#       개인 (76.081)
#       직접 (75.979)
#       시작 (75.132)
#      네이버 (74.862)
#      인프라 (74.283)
#      테스트 (73.753)
#       기록 (73.536)
#       자사 (73.431)

# %% [markdown]
#  top 100에서 중복되는 키워드들을 제거하고 차이가 있는 키워드만 추출해서 살펴보겠습니다.

# %%
keyword_counter = {}
for keywords in top_keywords:
    words, ranks = zip(*keywords)
    for word in words:
        keyword_counter[word] = keyword_counter.get(word, 0) + 1

common_keywords = {word for word, count in keyword_counter.items() if count == 3}
len(common_keywords)
# Out:
# 0

# %% [markdown]
# ## 키워드 분석

# %% [markdown]
# ## ROUGE-1,2,l 로 성능 평가

# %%
from rouge import Rouge
rank_list = ['기업', '개발', 'ai', '데이터', '플랫폼', '서비스', '언어', '보안', '디지털', '솔루션', '글로벌', '시장', '전문', '사업', '국내', '구글', '클라', '관리', '시스템', '코딩', '코드', '연구', '제품', '올해', 'nft', '공식']
rank_str = " ".join(rank_list)
model_out = [rank_str]
# '다양한', '관련', '것이', '새로운', '최근', '분석', '출처:', '활용', '따라', '한다.', '세계', '공동', '가장', '하는', '현재', '기존', '등을', '점유율은', '모든', '다른', '대해', '많은', '순위', '결과를', '또한', '대비', '10', '신규', '이용', '이를', '주요', '모두', '문제', '그러나', '여러', '출시', '이미', '생성', '가능', '이어', '공개', '발표', '이후', '최신', '전했다', '특히', '이상', '인기', '이는', '하지만', '지수', '이러한', '때문에', '핵심', '6월', '아이', '것은', '그리고', '이에', '같이', '동시에', '각각', '참여', '시간', '전체', '하나', '수준', '물론', '다수', '동안', '9월', '어떤', '전망', '혹은', '양자', '전자', '바로', '여전히'
reference = ["AI 출시 코딩 클라우드 개발 서비스 공개 언어 솔루션 프로그래밍 기반 플랫폼 트렌드 인기 체결 보안 기술 지수 티오베 PyPL 랭킹 발표 데이터 지원 맞손 시장 위한 사업 기업 메타버스 "]
rouge = Rouge()
rouge.get_scores(model_out, reference, avg=True)

# >>>
# {   'rouge-1': {   'f': 0.6279006234427593,
#                    'p': 0.8604497354497355,
#                    'r': 0.5273531655225019},
#     'rouge-2': {   'f': 0.3883256484545606,
#                    'p': 0.5244559362206421,
#                    'r': 0.32954545454545453},
#     'rouge-l': {   'f': 0.6282785202429159,
#                    'p': 0.8122895622895623,
#                    'r': 0.5369305616983636}}
# Out:
# {'rouge-1': {'r': 0.36666666666666664,
#   'p': 0.4230769230769231,
#   'f': 0.39285713788265303},
#  'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0},
#  'rouge-l': {'r': 0.2, 'p': 0.23076923076923078, 'f': 0.21428570931122462}}
