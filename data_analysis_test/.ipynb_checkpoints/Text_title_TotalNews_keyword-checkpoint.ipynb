# %% [markdown]
# # 1. 키워드 추출

# %% [markdown]
# ## 1-1 제목에서 추출

# %%
# 불필요한 경고 출력을 방지
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.model_selection import train_test_split

# %%
# '-' 깨짐 해결 모듈
import matplotlib.pylab as plt

import matplotlib as mpl

plt.rcParams["font.family"] = "Malgun Gothic"  # For Windows
plt.rcParams["font.size"] = 12
plt.rcParams["figure.figsize"] = (8,4)
print(plt.rcParams["font.family"])

# 마이너스 깨짐 해결
mpl.rcParams["axes.unicode_minus"] = False
# Out:
# ['Malgun Gothic']

# %% [markdown]
# ### 데이터 읽기

# %%
# techworld
df_bloter = pd.read_csv('../data_crawling_D/before_keywords/total_news_t_202306231600.csv')
print(df_bloter.shape)
# Out:
# (6641, 8)

# %%
df_bloter.head()
# Out:
#      news_date                                     news_title  \
# 0  2023.05.31.                대시보드로 보는 모니터링의 미래, '풀스택 옵저버빌리티'
# 1  2023.05.31.                      티오베 선정 ‘올해의 프로그래밍 언어’의 비밀
# 2   2023.05.31          글로벌 칼럼 | 맥이 비즈니스 환경에서 윈도우의 그늘을 벗어난 방법
# 3   2023.05.31                         IT 직원이 회사를 떠나는 12가지 이유
# 4   2023.05.31  엔비디아, 반도체기업 최초 시총 1조 달러 “AI 전쟁터의 유일한 무기 판매업체”
#
#                                         news_text_sm  \
# 0  IT 성능 관리를 위해 도입하던 ‘모니터링’이 한계에 달했다는 평가와 더불어, ‘옵...
# 1  좋은 프로그래밍 언어는 어떻게 정의할 수 있을까요? 상황에 따라 중요도는 다르겠지만...
# 2  2006년 1월, 애플은 비즈니스 세계에서 성공을 향한 중요한 발걸음을 내디뎠다. ...
# 3  IT 인력에 대한 수요가 증가한다. 인력 시장이 여전히 경색되어 있다. CIO로서는...
# 4  AI와 관련한 핵심 투자처를 물색하던 투자자들이 기반을 찾은 것으로 보인다. 30일...
#
#                                               url_in      news_writer  \
# 0     https://yozm.wishket.com/magazine/detail/2047/              조은정
# 1     https://yozm.wishket.com/magazine/detail/2046/              애옹킴
# 2  https://www.itworld.co.kr/t/55049/%EA%B8%80%EB...  Anirban Ghoshal
# 3  https://www.itworld.co.kr/t/55049/%EA%B8%80%EB...       Paul Krill
# 4  https://www.itworld.co.kr/t/55049/%EA%B8%80%EB...    Neal Weinberg
#
#   tags_string                                         thumb_addr news_site
# 0         NaN   https://yozm.wishket.com/media/news/2047/imag...      요즘IT
# 1         NaN  https://yozm.wishket.com/media/news/2046/image...      요즘IT
# 2         NaN  https://www.itworld.co.kr/files/itworld/ITW202...   ITWorld
# 3         NaN  https://www.itworld.co.kr/files/ciokr/2023/05/...   ITWorld
# 4         NaN  https://www.itworld.co.kr/files/itworld/ITW202...   ITWorld

# %%
df_bloter.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6641 entries, 0 to 6640
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   news_date     6641 non-null   object
#  1   news_title    6641 non-null   object
#  2   news_text_sm  6640 non-null   object
#  3   url_in        6641 non-null   object
#  4   news_writer   6641 non-null   object
#  5   tags_string   3987 non-null   object
#  6   thumb_addr    6619 non-null   object
#  7   news_site     6641 non-null   object
# dtypes: object(8)
# memory usage: 415.2+ KB

# %%
# df_techworld.columns
# idx 떼내기
df_bloter = df_bloter[[ 'news_date', 'news_title', 'news_text_sm', 'url_in',
       'news_writer', 'tags_string', 'thumb_addr', 'news_site']]

# %%
# df_recentit news_date 수정하기 (맨우측에 . 삭제)
df_bloter['news_date']= df_bloter['news_date'].str.replace(r'\.', '-', regex=True)
df_bloter['news_date'] = df_bloter['news_date'].str.rstrip()
df_bloter['news_date']

# [ 출처: https://seong6496.tistory.com/ ]
# Out:
# 0            2023-05-31-
# 1            2023-05-31-
# 2             2023-05-31
# 3             2023-05-31
# 4             2023-05-31
#               ...
# 6636    2022-05-31 10:36
# 6637    2022-05-31 10:12
# 6638    2022-05-31 09:48
# 6639    2022-05-31 08:49
# 6640          2022-05-31
# Name: news_date, Length: 6641, dtype: object

# %%
# 결측값 채우기
df_bloter.fillna('', inplace=True)
# df_itworld.fillna('')

# %% [markdown]
# ## KoNLPy로 단어 단위 분해

# %%
# datetime(날짜), os 호출

import datetime
import os
# 불용.txt 읽기 위해 csv 파일 호출
import csv
import re
# konlpy 호출
from konlpy.tag import Okt

# 자연어, 불용어 처리 및 wordcloud 생성을 위해
# 집계 메소드
from collections import Counter
from konlpy.tag import Komoran
# https://datascienceschool.net/03%20machine%20learning/03.01.01%20NLTK%20%EC%9E%90%EC%97%B0%EC%96%B4%20%EC%B2%98%EB%A6%AC%20%ED%8C%A8%ED%82%A4%EC%A7%80.html
from nltk.tokenize import word_tokenize

# %%
# 모듈화
def get_title_keywords(df):
    # 컬럼 'news_title' 가져오기 
    rdr = df['news_title'] 
    
    # Okt 객체 선언
    okt = Okt()
    ###  불용어 빼기
    # 불용어 파일 읽기
    stop_words = []
    with open('../data_analysis_test/불용.txt', 'r', encoding='utf-8') as file:
       stop_words = file.read().splitlines()
    
    h_word_list = []
    for w_bundle in rdr:
      # print(okt.nouns(w_bundle))
        list = okt.nouns(w_bundle)
        # 특수문자 제거
        tokens = ",".join(list)
        tokens = re.sub('[\{\}\[\]\/?.;:|\)*~`!^\-_+<>@\#$%&\\\=\(\'\"]', '', tokens)
        list = tokens.split(",")
        # 한글자인 명사, ',' 빼기 (예외:웹,앱,폰,챗)
        for i,v in enumerate(list):
            if len(v) < 2 and (v != '웹' and v != '앱' and v != '폰' and v != '챗'):
                list.pop(i)
            elif v == ',':
                list.pop(i)
            # 불용어 제거
            elif i in stop_words:
                list.pop(i)
        list_str = ",".join(list)
       
        h_word_list.append(list_str)
    return h_word_list
    # print(h_word_list)
    # len(techworld_h_word_list)

bloter_h_word_list = get_title_keywords(df_bloter)

# %% [markdown]
# ## 해당 리스트 목록을 새로운 컬럼으로 추가

# %%
df_bloter['news_key'] = bloter_h_word_list
df_bloter['news_key']
# Out:
# 0                 대시보드,모니터링,미래,스택,옵저버
# 1                 베,선정,올해,프로그래밍,언어,비밀
# 2            글로벌,칼럼,비즈니스,환경,윈도우,그늘,방법
# 3                         직원,회사,가지,이유
# 4       엔비디아,반도체,기업,최초,달러,전쟁,무기,판매,업체
#                     ...
# 6636          그룹,개사,종로타워,터전,그린,캠퍼스,출범
# 6637         앤듀로샛,로켓,관측,엣지,컴퓨팅,시스템,공급
# 6638               노르딕,브레이브,리지,플랫폼,공급
# 6639           정통부,디지털,트윈,실증,사업,본격,착수
# 6640                 타입,스크립트,출시,노드,지원
# Name: news_key, Length: 6641, dtype: object

# %% [markdown]
# ## 1-2 news_text_sm에서 키워드 추출하기

# %%
# 모듈화
def get_text_keywords(df):
    # 컬럼 'news_title' 가져오기 
    rdr = df['news_text_sm'] 
    
    # Okt 객체 선언
    okt = Okt()
    ###  불용어 빼기
    # 불용어 파일 읽기
    stop_words = []
    with open('../data_analysis_test/불용.txt', 'r', encoding='utf-8') as file:
       stop_words = file.read().splitlines()
    
    h_word_list = []
    for w_bundle in rdr:
      # print(okt.nouns(w_bundle))
        list = okt.nouns(w_bundle)
        # 특수문자 제거
        tokens = ",".join(list)
        tokens = re.sub('[\{\}\[\]\/?.;:|\)*~`!^\-_+<>@\#$%&\\\=\(\'\"]', '', tokens)
        list = tokens.split(",")
        # 한글자인 명사, ',' 빼기 (예외:웹,앱,폰,챗)
        for i,v in enumerate(list):
            if len(v) < 2 and (v != '웹' and v != '앱' and v != '폰' and v != '챗'):
                list.pop(i)
            elif v == ',':
                list.pop(i)
            # 불용어 제거
            elif i in stop_words:
                list.pop(i)
        list_str = ",".join(list)
       
        h_word_list.append(list_str)
    return h_word_list
    # print(h_word_list)
    # len(techworld_h_word_list)

bloter_txt_word_list = get_title_keywords(df_bloter)

# %%
df_bloter['news_txt_key'] = bloter_txt_word_list
df_bloter['news_txt_key']
# Out:
# 0                 대시보드,모니터링,미래,스택,옵저버
# 1                 베,선정,올해,프로그래밍,언어,비밀
# 2            글로벌,칼럼,비즈니스,환경,윈도우,그늘,방법
# 3                         직원,회사,가지,이유
# 4       엔비디아,반도체,기업,최초,달러,전쟁,무기,판매,업체
#                     ...
# 6636          그룹,개사,종로타워,터전,그린,캠퍼스,출범
# 6637         앤듀로샛,로켓,관측,엣지,컴퓨팅,시스템,공급
# 6638               노르딕,브레이브,리지,플랫폼,공급
# 6639           정통부,디지털,트윈,실증,사업,본격,착수
# 6640                 타입,스크립트,출시,노드,지원
# Name: news_txt_key, Length: 6641, dtype: object

# %%
# df_techworld

# %% [markdown]
# ### 'news_key', 'news_txt_key' 값 합치기

# %%
df_bloter['total_keywords'] = df_bloter[['news_key', 'news_txt_key']].apply(','.join, axis=1)
print(df_bloter)
# Out:
#              news_date                                     news_title  \
# 0          2023-05-31-                대시보드로 보는 모니터링의 미래, '풀스택 옵저버빌리티'
# 1          2023-05-31-                      티오베 선정 ‘올해의 프로그래밍 언어’의 비밀
# 2           2023-05-31          글로벌 칼럼 | 맥이 비즈니스 환경에서 윈도우의 그늘을 벗어난 방법
# 3           2023-05-31                         IT 직원이 회사를 떠나는 12가지 이유
# 4           2023-05-31  엔비디아, 반도체기업 최초 시총 1조 달러 “AI 전쟁터의 유일한 무기 판매업체”
# ...                ...                                            ...
# 6636  2022-05-31 10:36                   SK그룹 6개사 종로타워에 새 터전 그린캠퍼스 출범
# 6637  2022-05-31 10:12                  IBM 앤듀로샛 로켓에 관측용 엣지컴퓨팅 시스템 공급
# 6638  2022-05-31 09:48             노르딕 브레이브리지 IoT 플랫폼에 nRF9160 SiP 공급
# 6639  2022-05-31 08:49                     과기정통부 디지털트윈(DW) 실증사업 본격 착수
# 6640        2022-05-31               타입스크립트 4.7 출시…“노드.js 16용 ESM 지원”
#
#                                            news_text_sm  \
# 0     IT 성능 관리를 위해 도입하던 ‘모니터링’이 한계에 달했다는 평가와 더불어, ‘옵...
# 1     좋은 프로그래밍 언어는 어떻게 정의할 수 있을까요? 상황에 따라 중요도는 다르겠지만...
# 2     2006년 1월, 애플은 비즈니스 세계에서 성공을 향한 중요한 발걸음을 내디뎠다. ...
# 3     IT 인력에 대한 수요가 증가한다. 인력 시장이 여전히 경색되어 있다. CIO로서는...
# 4     AI와 관련한 핵심 투자처를 물색하던 투자자들이 기반을 찾은 것으로 보인다. 30일...
# ...                                                 ...
# 6636  SK그룹에서 친환경 사업을 담당하는 관계사가 서울 종로구에 마련된 ‘그린캠퍼스’에 ...
# 6637  IBM이 최근 엔듀로샛이 발사한 우주로켓에 IBM의 오픈소스 하이브리드클라우드 인공...
# 6638  노르딕세미컨덕터가 일본 IoT 솔루션 기업인 브레이브리지(Braveridge)의 I...
# 6639  과학기술정보통신부가 한국지능정보사회진흥원(NIA) 정보통신산업진흥원(NIPA)과 함...
# 6640  ‘타입스크립트 4.7(TypeScript 4.7)’이 프로덕션 릴리즈로 출시됐다. ...
#
#                                                  url_in       news_writer  \
# 0        https://yozm.wishket.com/magazine/detail/2047/               조은정
# 1        https://yozm.wishket.com/magazine/detail/2046/               애옹킴
# 2     https://www.itworld.co.kr/t/55049/%EA%B8%80%EB...   Anirban Ghoshal
# 3     https://www.itworld.co.kr/t/55049/%EA%B8%80%EB...        Paul Krill
# 4     https://www.itworld.co.kr/t/55049/%EA%B8%80%EB...     Neal Weinberg
# ...                                                 ...               ...
# 6636  https://www.itbiznews.com//news/articleView.ht...               박인환
# 6637  https://www.itbiznews.com//news/articleView.ht...               오현식
# 6638  https://www.itbiznews.com//news/articleView.ht...               최태우
# 6639  https://www.itbiznews.com//news/articleView.ht...               김소현
# 6640  https://www.itworld.co.kr/t/61023/%EA%B0%9C%EB...  Anirban Ghoshal?
#
#                                           tags_string  \
# 0
# 1
# 2
# 3
# 4
# ...                                               ...
# 6636                          #친환경,#탄소중립,#그린캠퍼스,#SK그룹
# 6637                            #앤듀로샛,#IBM,#우주,#우주 산업
# 6638  #산업용 IoT,#IIoT,#시스템인패키지,#SiP,#nRF9160,#노르딕세미컨덕터
# 6639        #디지털트윈,#DW,#시뮬레이션,#탄소저감,#실증사업,#NIA,#과기정통부
# 6640
#
#                                              thumb_addr news_site  \
# 0      https://yozm.wishket.com/media/news/2047/imag...      요즘IT
# 1     https://yozm.wishket.com/media/news/2046/image...      요즘IT
# 2     https://www.itworld.co.kr/files/itworld/ITW202...   ITWorld
# 3     https://www.itworld.co.kr/files/ciokr/2023/05/...   ITWorld
# 4     https://www.itworld.co.kr/files/itworld/ITW202...   ITWorld
# ...                                                 ...       ...
# 6636  https://www.cwn.kr./thumbnail/202205/72853_674...     ITBiz
# 6637  https://www.cwn.kr./thumbnail/202205/72831_674...     ITBiz
# 6638  https://www.cwn.kr./thumbnail/202205/72852_674...     ITBiz
# 6639  https://www.cwn.kr./thumbnail/202205/72849_674...     ITBiz
# 6640  https://www.itworld.co.kr/files/ciokr/2022/05/...   ITWorld
#
#                            news_key                   news_txt_key  \
# 0               대시보드,모니터링,미래,스택,옵저버            대시보드,모니터링,미래,스택,옵저버
# 1               베,선정,올해,프로그래밍,언어,비밀            베,선정,올해,프로그래밍,언어,비밀
# 2          글로벌,칼럼,비즈니스,환경,윈도우,그늘,방법       글로벌,칼럼,비즈니스,환경,윈도우,그늘,방법
# 3                       직원,회사,가지,이유                    직원,회사,가지,이유
# 4     엔비디아,반도체,기업,최초,달러,전쟁,무기,판매,업체  엔비디아,반도체,기업,최초,달러,전쟁,무기,판매,업체
# ...                             ...                            ...
# 6636        그룹,개사,종로타워,터전,그린,캠퍼스,출범        그룹,개사,종로타워,터전,그린,캠퍼스,출범
# 6637       앤듀로샛,로켓,관측,엣지,컴퓨팅,시스템,공급       앤듀로샛,로켓,관측,엣지,컴퓨팅,시스템,공급
# 6638             노르딕,브레이브,리지,플랫폼,공급             노르딕,브레이브,리지,플랫폼,공급
# 6639         정통부,디지털,트윈,실증,사업,본격,착수         정통부,디지털,트윈,실증,사업,본격,착수
# 6640               타입,스크립트,출시,노드,지원               타입,스크립트,출시,노드,지원
#
#                                          total_keywords
# 0               대시보드,모니터링,미래,스택,옵저버,대시보드,모니터링,미래,스택,옵저버
# 1               베,선정,올해,프로그래밍,언어,비밀,베,선정,올해,프로그래밍,언어,비밀
# 2     글로벌,칼럼,비즈니스,환경,윈도우,그늘,방법,글로벌,칼럼,비즈니스,환경,윈도우,그늘,방법
# 3                               직원,회사,가지,이유,직원,회사,가지,이유
# 4     엔비디아,반도체,기업,최초,달러,전쟁,무기,판매,업체,엔비디아,반도체,기업,최초,달...
# ...                                                 ...
# 6636    그룹,개사,종로타워,터전,그린,캠퍼스,출범,그룹,개사,종로타워,터전,그린,캠퍼스,출범
# 6637  앤듀로샛,로켓,관측,엣지,컴퓨팅,시스템,공급,앤듀로샛,로켓,관측,엣지,컴퓨팅,시스템,공급
# 6638              노르딕,브레이브,리지,플랫폼,공급,노르딕,브레이브,리지,플랫폼,공급
# 6639      정통부,디지털,트윈,실증,사업,본격,착수,정통부,디지털,트윈,실증,사업,본격,착수
# 6640                  타입,스크립트,출시,노드,지원,타입,스크립트,출시,노드,지원
#
# [6641 rows x 11 columns]

# %% [markdown]
# ### 중복 키워드 처리

# %%
# from collections import OrderedDict

# list = '티맥스,티베로,인텔,코리아,비즈니스,연속성,혁신,전략,웨비,개최,티맥스,티베로,인텔,코리아,비즈니스,연속성,혁신,전략,웨비,개최'
# list_sep = list.split(",")
# list_sep

# a = " ".join(OrderedDict.fromkeys(list_sep))
# print(a)

# %%
from collections import OrderedDict

t_keyword_list = []

for keys in df_bloter['total_keywords']:
    # print([keys]) # 일단 전부 ,로 split()해줘야 단어끼리로 분리됨
    keys_list = keys.split(",")
    key_list_str = ','.join(OrderedDict.fromkeys(keys_list))
    # print(key_list_str)
    # 2차원 리스트 만들기
    t_keyword_list.append(key_list_str)

t_keyword_list
# Out:
# ['대시보드,모니터링,미래,스택,옵저버',
#  '베,선정,올해,프로그래밍,언어,비밀',
#  '글로벌,칼럼,비즈니스,환경,윈도우,그늘,방법',
#  '직원,회사,가지,이유',
#  '엔비디아,반도체,기업,최초,달러,전쟁,무기,판매,업체',
#  '쿠팡,디자인,시스템,구축',
#  '웹,메타,버스,캐리,시네마,공개,동시,사전예약,돌입',
#  '중대,전환,인공,지능,트렌드,활용',
#  '티맥스,티베로,인텔,코리아,비즈니스,연속성,혁신,전략,웨비,개최',
#  '롯데,운송,플랫폼,리스,확대,적용',
#  '지에스,아이엘,삼성,엔지니어링,사우디,법인,스마트,안전,솔루션,계약,체결',
#  '한국,레노버,세대,요가,신제품,출시',
#  '텔레콤,양자,보안,폰,갤럭시,퀀텀,출시',
#  '하이닉스,나노,세대,인텔,데이터,센터,호환성,검증,돌입',
#  '차세대,공개,모바일,기기,성능,업그레이드,기대',
#  '노키아,삼지,전자,옥외,빌딩,환경,테스트,완료',
#  '아이폰,프로,모델,디스,플레,크기',
#  '챗,자신감,엔비디아,달러,반도체,기업,하나',
#  '한국,레노버,세대,요가,신제품,출시',
#  '롯데,리스,적용,유통,물류,혁신,가속',
#  '테크,저가,클라우드,경쟁,본격,하나,산업,밑그림',
#  '레드햇,한전,전력,에너지,분야,공동,사업,추진',
#  '세대,절반,이상,사용,온라인,계정,보유,베리타스',
#  '전경련,사주,소각,의무,기업,경영,위협,수도',
#  '구글,코리아,기보,기업은행,크리에이터,장지원,파트너',
#  '상관관계,인과관계',
#  '이콘,미래,세대,것',
#  '올림플래닛,포레스트,반려동물,메타,버스,장례,서비스',
#  '기술,혁신,연구소,연구,상업,활용,오픈,소스,팰컨,출시',
#  '기계,유럽,기술,강국,공동,연구,확대,로봇,제조,분야,협력',
#  '폭스바겐,소프트웨어,활용,자율,주행,서비스,탑승객,관리,시스템,개발',
#  '디자인,보호,일부,개정안,국회,본회의,통과',
#  '클라우드,선택,순위,보안',
#  '해외,스타트업,노트북,개발,업무,혼합,현실,사용,대감',
#  '윈도우,파일럿,업그레이드',
#  '가상,네트워크,어시스턴트,챗,통합',
#  '티맥스,그룹,인텔,파트너,어워드,수상',
#  '컴투,버스,정부,주관,실감,콘텐츠,핵심,기술,개발,사업,공동,연구기관,선정',
#  '진원,내달,넥스트,라이즈,서울,동관,운영',
#  '네이버,클라우드,호반,건설,국내,현장,이음,실증',
#  '누리,차,발사,성공,항공우주,시대',
#  '블로그,넷플릭스,계정,공유,제한,주기,게임,이유',
#  '리더,개발자,가지,기술',
#  '초보,개발자,완전,기초,지식,실무',
#  '지그재그,팝업,스토어,불,일견,현장',
#  '지그재그,팝업,스토어,불,일견,현장',
#  '빌드,기반,분석,플랫폼,브릭,공개',
#  '인텔,나노,내장,애질,렉스,양산,개시',
#  '오라클,협력,원,제공',
#  '에릭슨,안테나,결합,상용,완료',
#  '엔비디아,기업,생,협력,강화',
#  '퓨어,스토리,미디어,파일,오브젝트,공급',
#  '강화,환경,규제,단거리,비행,금지법,시행',
#  '마인,컴퍼니,기반,검색,솔루션,서핑,정식,출시',
#  '에이수스,시리즈,그래픽카드,출시',
#  '레드햇,서비스,앤서블,라이트,스피드,공개',
#  '출시,임박,모토로라,더블,폰,화면,주사,지원,전망',
#  '에이서,마켓,빅스,마일,데이,게이,노트북,달성',
#  '무하,관광,재단,서류,평가,프리즘,제공',
#  '뤼튼,아시아,컨퍼런스,개최',
#  '메타,대규모,다국어,음성인식,모델,오픈소스,공개',
#  '알리바바,클라우드,선택,비용,보안,중요시',
#  '로크,하이,이드,센터,자동,제어,시스템,공급,계약',
#  '발전,방향,탐구,산학,공동,세미나,개최',
#  '이노,그리드,부문,디지털,혁신,클라우드,컨설팅,사업,수주',
#  '네이버,한국,수자원공사,관리,디지털,트윈,서비스,구축,협력',
#  '지역,상생,성장,도모,삼성,스마트,공장,지원,사업,개시',
#  '대비,과장,광고,통신,과징금,철퇴',
#  '제조업,성공,고객,혁신,트렌드,포스,전체,경험,관리,전략',
#  '플랫폼,백서',
#  '지그재그,앱,팝업,스토어,운영,차별',
#  '지그재그,앱,팝업,스토어,운영,차별',
#  '가입,카카오,사용,전력,재생에너지,전환',
#  '실제,마주,보고,클레,실시간,디지털,휴먼,챗봇,런칭',
#  '국외,기술,유출,지재권,침해,특허청,국제,공조,수사,체계,구축',
#  '의학,전문가,사용,위험성,경고',
#  '매스,스코리아,청정,에너지,스케,우주,탐사,혁신,솔루션,기여',
#  '닉스,넥스트,신규,솔루션,서비스,공개',
#  '사용자,신용카드,정보,암시장,평균,거래',
#  '항공,교통,서비스,평가,발표,제주항공,시간,준수,안전성,상위',
#  '인텔,위,개방,포트폴리오,공개',
#  '어댑티브,싱크,디스플레이,표준,버전,발표',
#  '카카오,사우디,관광,청과,콘텐츠,인프라,고도화,협력,논의',
#  '메타,참전,테크,반도체,시장,속도,이유',
#  '마이크로,닉스,대만,컴퓨텍스,참가',
#  '아이티,임베디드,솔루션,차량,네트워크,프로세서,지원',
#  '베리타스,파트너,프로그램,개편,채널,대상,리소스,개선,지원',
#  '오라클,클라우드,프라다,기반,리테일,솔루션,구축',
#  '롤스로이스,차세대,엔진,아키텍처,울트라,테스트,완료',
#  '반도체,센터,구축,달러,투자',
#  '학,법조,외부,전문가,참여,정보보호,신설',
#  '리플,테이블,코인,개발,지원,플랫폼,론칭',
#  '구글,프론트엔드,성공,지표',
#  '오픈소스,사용',
#  '네이버,카카오,뉴스,평위,중단,인터넷,신문,심사,재개,일정,공개,하라',
#  '네이버,카카오,뉴스,평위,중단,인터넷,신문,심사,재개,일정,공개,하라',
#  '클레,기반,영상,솔루션,독일,디자인,어워드,본상,관왕',
#  '네이버,사무,총장,디지털,전환,도전,기회',
#  '로지텍,웰케어,브랜드,협업,진행',
#  '한컴,유비,마이크로,디지털,안전,시장,공략,본격',
#  '신규,메랄,소프트웨어,플랫폼,출시',
#  '보안,포트폴리오,확장,시큐리티,레이더,스위트,공개',
#  '클라우드,머전,액침,냉각,시스템,적용,확대',
#  '미스트,접근,보장,서비스,발표,클라우드,연결,보안,강화,초점',
#  '마이크론,제품,구매,중단,경고,상무부,근거,조치,비난',
#  '비즈,마켓,기업,고객,솔루션,사업자,프로모션',
#  '워,엘리,베이트,서울,개최',
#  '스토리,코믹스,재팬,달러,규모,수출,상담,성과',
#  '애플,아이패드,공개,베타,버전,배포',
#  '엔비디아,서비스,나우,파트너,엔터프라이즈,구축',
#  '이스트소프트,휴먼,비즈니스,모델,글로벌,확장,위해,방문',
#  '소니,다음,스마트폰,갤플,모습,클램셸,형태,더블,폰,출시,전망,제기',
#  '제조,산업,트렌드,베스트,프랙,티스,컨퍼런스,내달,개막',
#  '붕괴,융합,통한,혁신,최신,기업,동향,가지',
#  '중국,마이크론,제품,사용,금지,조치,미국,무역,분쟁,심화',
#  '소고기,도메인,드리븐,실현,조환,인,개발,리더',
#  '파,이콘,한국,사랑,이유',
#  '메타,옥타곤,버스,버전,출시',
#  '네이버,카카오,뉴스,평위,잠정,중단,제휴,모델',
#  '네이버,카카오,뉴스,평위,잠정,중단,제휴,모델',
#  '초슬림,경량,고성능,노트북,젠북,출시',
#  '트루,테크놀로지,기업은행,실시간,신분증,사본,검증,솔루션,도입,추진,사업,수주',
#  '네이버,초기,사업자,지원',
#  '아일랜드,정부,메타,벌금,폭탄,개인정보보호법,위반',
#  '발광,효율,그래핀,퀀텀닷,결합,혼합,차원,소재,개발',
#  '시큐리티,레이더,스위트,신제품,출시',
#  '로지텍,소음,무선,마우스,출시',
#  '스핀,글로벌,베트남,소프트,아이,스마트,시티,사업,협력,체결',
#  '에이수스,슬림,경량,고성능,노트북,젠북,시리즈,출시',
#  '기술,연구,올해,우수,논문,선정',
#  '카카오,웹툰,환경,운영,협력,강화',
#  '대흥,정보,카카오,모빌리티,잡고,공영,주차장,서비스,확대',
#  '지능,기반,구축,사업,설계,보고,개최',
#  '독립,변수',
#  '로우,코드,열풍,개발자,일자리',
#  '아일랜드,섀넌,제조,시설,확충',
#  '퓨어,스토리,플래시,레이,파일,서비스,출시',
#  '서울,리전,쿼리,지원',
#  '인텔,클라우드,역량,확대,성능,효율,개선,협업',
#  '올리브,네트웍,지니,전환,지원',
#  '브이엔티,아웃,시스,템즈,네트워킹,포럼',
#  '에이수스,크리에이터,및,그래픽카드,출시',
#  '라이,와이즈,챗,플러그인,출시,개인,맞춤,엔터테인먼트,추천,제공',
#  '에스,시스템,시스코,프리미어,프로,바이,자격,획득',
#  '슈나이더,탄소,중립,사업,개발,체결',
#  '스위스,양자,기술,협력,강화,정통부,과학기술,토론회',
#  '오픈,챗,아이폰,아이패드,버전,공식,앱,출시',
#  '구글,클라우드,세계,카카오,웹툰,서비스,환경,구축,지원',
#  '마이크로웨이브,주파수,결합,기술,상용',
#  '이스트소프트,다국어,발화,휴먼,데빈,출시,글로벌,경쟁력,강화',
#  '에쓰,테크놀로지,한국,인공,지능,기반,확대,위해,협력',
#  '뤼튼,코드,개발,툴빌더,전면,개방',
#  '삼성,물류,디지털,전환,선언,첼로,스퀘어,로드맵,공유',
#  '에드,테크,역량,강화,메조,미디어,센터,카피라이터,도입,추진',
#  '미국,대법원,테러,단체,악용,구글,트위터,책임',
#  '개발자,아두,재현,예제,활용',
#  '이노,그리드,강원도,클라우드,전환,컨설팅,사업,단독,수주',
#  '인트,플로우,돼지,분석,기술,특허,등록,완료',
#  '퀸텟,시스,템즈,로우,코드,개발,플랫폼,대규모,업그레이드',
#  '하이,케어,기반,치매,조기,예측,국책,과제,참여',
#  '인덴트,코퍼레이션,고객,리뷰,분석,인사이트,공개',
#  '네트워크,기술,사회,문제,해결,비욘드,랩스,이니셔티브,발표',
#  '하이닉스,동반성,경영,실천,공동,선언',
#  '삼성,전자,업계,최선,나노,양산',
#  '글로벌,네트워킹,확대,진원,콘텐츠,비즈니스,포럼',
#  '영림,소프트,규모,공공,계약,체결',
#  '사파이어,개최,기반,미래,비즈니스,제시',
#  '삼성,나노,양산,개시,고성능,용량,확대,공급',
#  '유아,패스,플랫폼,업데이트,기능,강화',
#  '모토로라,플립,더블,레이저,폰,공개,예고',
#  '용인,신규,트레이닝,센터',
#  '클라우드,전반,데이터,액세스,간소화,오라클,관리,혁신',
#  '엑스,게이트,양자암호,통신,기반,개발',
#  '인공,지능,기반,바이어,발굴,중,기부,팁스,선정',
#  '세대,직장,선택,기준,밸,자기계발,급여,한국,딜로이트,그룹',
#  '한국,비즈니스,핵심,아젠다,지속가능성,레노버',
#  '백년,전통,기술,결합,테니스,코드,바람',
#  '개발자,생활,이,가지',
#  '코드,가독성,자바,람다,함수,인터페이스',
#  '안랩,사칭,기업,페이스북,계정,피싱,메일,주의,당부',
#  '왓츠앱,사용자,프라이버시,채팅,기능,배포',
#  '인프라,운영,재정,회복,탄력성,준비',
#  '항균,유리,파우더,개발,전자,기능,소재,사업,본격',
#  '슈나이더,모듈,구성,적용,시스,아일랜드,모터,스타,공개',
#  '대화,챗봇,열풍,이면,열정,페이,논란',
#  '뷰노,의료,관련,미국,특허,획득,시장,공략,본격',
#  '시큐리티,벤치,출시,로,보안,강화',
#  '특허,챗봇,상담,서비스,개선',
#  '아일랜드,센터,유로,신규,투자,발표',
#  '아이,와이파이,지원,무선,침입,방지,시스템,출시',
#  '휴면,계정,정리,구글,최근,비활,삭제,조치',
#  '에이,럭스,코딩,로봇,비누,신규,특허,추가,확보',
#  '카카오,카톡,오픈,채팅,별도,이유',
#  '카카오,카톡,오픈,채팅,별도,이유',
#  '카카오,오픈,채팅,탭,신설',
#  '빌드,시대,혁신,기술,공개',
#  '디지털,작업,대다수,생산,모니터링,가트너',
#  '그것,사이버,범죄,온상,다크,웹',
#  '스핀,글로벌,옵스,나우,기능,쿠베,익스플로러,출시',
#  '오라클,데이터,관리,자율,운영,웨어하우스,기능,발표',
#  '슈나이더,트릭,코리아,스마트,디지털,모터,스타,소개',
#  '하나,금융,통신,데이터,결합,소외,계층',
#  '아쿠아,시큐리티,파이프라인,무결,스캐닝,제공,공급망,보안,강화',
#  '복권,사업,디지털,안전,파수,수탁,보안,솔루션,공급',
#  '스퀘어,정보보호,국제,표준,인증,획득',
#  '맥스,등,글로벌,기술,협력,글래스,적용,확대',
#  '차세대,지능,로봇,연결,통합,테크,써밋,개최',
#  '구글,가짜,이미지,확산,배포',
#  '엔비디아,싱텔,가속,컴퓨팅,플랫폼,공급',
#  '지멘스,부문,가트너,매직,쿼드런트,리더,선정',
#  '삼성,전기,세계,최고,용량,차용,개발',
#  '스테이지,개최,글로벌,리딩,기업,목표',
#  '한국,전파,진흥,협회,클라우드,컴퓨팅,인력,스쿨',
#  '인천,전세버스,디지털,음주,측정기,보급',
#  '리다,노,종원,데이비드,딕슨,각자,대표,체제,전환',
#  '삼성,전자,국내,노트북,시장,점유,돌파',
#  '클라우드,데이터,센터,엣지,인프라,가지,트렌드,가트너',
#  '미디어,신성,지금,뉴스,매체,바이스,파산,보호,신청',
#  '존,클라우드,상반기,일본,스타트업,동향,분석,리포트,발행',
#  '라이선스,계약,마이크로소프트,블리자드,인수,승인',
#  '자바,개발자,컨테이너,이미지,빌드',
#  '나스,미디어,기반,광고,최적화,솔루션,스위트,공개',
#  '화해,뷰티,기능,정보,탐색,서비스,오픈',
#  '화해,뷰티,기능,정보,탐색,서비스,오픈',
#  '에이트,코스닥,상장,예비,심사,청구,일정,돌입',
#  '고도,보안,전문성,양자,기술,공개',
#  '디지털,트윈,특허,출원,최근,평균,성장',
#  '기업,개방,데이터,구축',
#  '네이버,클립,서비스,거래,배',
#  '애플,프로,테스트,공정,채택,전망',
#  '전파,진흥,중소,조사,단말,검증,환경,제공',
#  '로지텍,롯데,백화점,부산,본점,브랜드,오픈',
#  '한국,에코,플랜트,클라우드,기반,폰,공급',
#  '그룹,링컨,센터,주관,뉴욕,문화,행사,후원,글로벌,스토리,일환',
#  '로그,프레,조달청,나라장터,소나,등록',
#  '부동산,여행,라벨,근무,세상,가지',
#  '광고,금제,이득,디즈니,플러스,가입자,정체,꿈쩍,이유',
#  '엔터프라이즈,클라우드,동향,가지',
#  '티맥스소프트,파트너,에코,시스템,강화,시장,공략,가속',
#  '소상,공인,성공,프로젝트,네이버,무엇',
#  '소상,공인,성공,프로젝트,네이버,무엇',
#  '삼성,업계,최초,개발,연내,양산,시작',
#  '라이온,네이버,프리미엄,파트너,등급,획득',
#  '전선,광케이블,친환경,케이블,보빈,도입',
#  '데이터',
#  '전공자,개발자,취업,준비',
#  '젤리,스페이스,원더풀,플랫폼,인공,지능,로봇,산업,협약,체결',
#  '블록,오디세이,한국,에너지,기술평가원,지원,전기차,배터리,중고,거래,플랫폼,사업,참여',
#  '이성,이노,책임,연구원,올해,발명왕,선정',
#  '국내,장,휴먼,트레이너,선',
#  '로우,코드,개발,환경,지원,비주,스테이,버전,업데이트',
#  '베리타스,법무,법인,데이터,컴플라이언스,공동,대응',
#  '이수,시스템,챗,기반,서비스,론칭',
#  '정부,바이오,허브,보스턴,국내,기업,진출,거점,구축',
#  '네이버,카카오,검색,기준,공개,자율,규제,방안',
#  '네이버,카카오,검색,기준,공개,자율,규제,방안',
#  '구글,클라우드,기업,고객,개방,데이터,파트너,발표',
#  '코오롱,니트,중대,건물,전기,화재,예방,솔루션,개발',
#  '한국,엡손,참가,고속,정밀,로봇,솔루션,공개',
#  '에쓰,테크놀로지,마이크로소프트,애저,엑스,퍼트,자격,획득',
#  '엘리,먼트,그레이,정밀,스위치,공식,유통업체,지정',
#  '코어,아이,파트너,강화,사업,모색',
#  '북부,경찰청,기반,누구,비즈,공급,확산',
#  '카카오,본부,주관,회의,디지털,안전,성과,모범,사례,공유',
#  '올해,주목,데이터,분석,트렌드,가치,최적화,리스크,관리,옵저버',
#  '삼성,나인,솔루션,엠로,협력,글로벌,공급망,시장,공략',
#  '마이크로,닉스,플레이,엑스포,참가',
#  '네이버,카카오,검색,노출,순서,기준,공개',
#  '네이버,카카오,검색,노출,순서,기준,공개',
#  '요금,보안,동시,중견,기업,전용,회선,비즈,출시',
#  '바이,퓨처,그룹,조사,성능,우위,입증',
#  '해외,컨설팅,기업,유권자,대상,테크,업계,규제,관련,견해,설문,조사,진행',
#  '모바일,통일,강화,네이버,메인,페이지,개편',
#  '오픈,엣지,노바,칩스,컨트롤러,탑재',
#  '화웨이,맥북,프로,메이트,라인업,세대,인텔,프로세서,채택',
#  '루스,첨단,소재,신규,생산,기지,착공,발광,영역,확대',
#  '티맥스,오피스,앱,제작,솔루션,상반기,출시,예정',
#  '마이크로,디스플레이,탑재,아이폰,애플,로드맵,포함',
#  '메타,버스,영상,저작권,보호,기술,특허,출원',
#  '삼성,탄소,중립,목표,재생에너지,기술,개발',
#  '비즈니스,생,플랫폼,왓슨,발표',
#  '힐셔,싱글,페어,이더넷,시스템,얼라이언스,가입',
#  '대중화,발짝,마이크로소프트,파일럿,지원,앱,테스트,규모,확대',
#  '엔지니어,방법',
#  '옵스,여행,입문,안내서',
#  '트렌드,포스,최대,하락',
#  '로봇,한국,로봇산업,진흥,서비스로봇,실증,사업,참여',
#  '에쓰,푸드,테크,협력,식품,공급망,전반,기술,접목',
#  '네이버,화면,모바일,중심,개편,이유',
#  '네이버,화면,모바일,중심,개편,이유',
#  '스트,시스,캐드,프린트,프로,소프트웨어,출시',
#  '삼성,전자,나주시,주민,수요,반응,서비스,시범,사업,합류',
#  '기업,생산,플랫폼,슬랙,대화,서비스,포함,신규,기능,발표',
#  '국민,사회,책임,이행,수준,기업,제품,우선,구매',
#  '국제,인공,지능,대전,풍요,빈곤,기술',
#  '비즈니스,파운데이션,모델,지원,왓슨,플랫폼,발표',
#  '소상,공인,주문,서비스,하이,출시',
#  '슈나이더,트릭,대한민국,기계,설비,전시회,참가',
#  '전자,앱,나주,에너지,자립,도시,구축,참여',
#  '웹,기반,메타,버스,영상,저작권,보호,기술,특허,출원',
#  '정통부,반도체,미래,기술,로드맵,공개',
#  '숭실대,사이버,보안,분야,전문,인재,양성',
#  '특허청,유럽,통합,특허,제도,설명',
#  '전장,반도체,인,피니언,규모,노어,플래시,영역,이유',
#  '이니텍,다큐,제로,계약,체결',
#  '화웨이,금지,조치,합류,독일,지정학적,관계,방정식',
#  '사이버,보안,위험,숫자,표현',
#  '코드,리뷰,켄트,의,아이디어,접목',
#  '외신,실시간,번역,제공,구글,글래스,지금,출시,적기',
#  '원티드,매출,하락,성장,자신,이유',
#  '원티드,매출,하락,성장,자신,이유',
#  '에이서,마켓,빅스,마일,데이,노트북,신제품,할인',
#  '루닛,미국,상종,학회,연구,초록,발표',
#  '애니,프롭,테크,기술,교환,체결',
#  '삼성,전자,갤럭시,워치,불규칙,심장,리듬,기능,미국,승인,획득',
#  '로봇,절차,착수,내년,코스닥,상장,목표',
#  '통한,맞춤,광고,전략,플랫폼,도입,이유',
#  '마이크로,닉스,금천구,시설,후,원금,전달',
#  '교육,플랫폼,코디,로봇,교구,업데이트',
#  '아이폰,프로,햅틱,버튼,채택,가능성,제기',
#  '코리아,전문,프로그래머,인력',
#  '코스닥,상장,예비,심사,청구,연내,목표',
#  '인천,입체,통신,실증,협력',
#  '테크,실적,선방,인플레,경기,침체,시장,회복,대감',
#  '카카오,아모레퍼시픽,비즈니스,동반성,협력',
#  '주니어,개발자,주요,프로토콜',
#  '존,바이트,플러스,라라,스테이션,기술,고도화',
#  '주주,사외이사,후보,추천,도입,사내,이사,참여,배제',
#  '약국,플랫폼,약사,스케,솔루션,고도화',
#  '뉴렐릭,옵저버,어시스턴트,그록,공개',
#  '코딩,트렌드,프로그래밍,언어,순위,발표,타입,스크립트,위,포함',
#  '클라우드,복권,수탁,사업,수주',
#  '퓨어,스토리,포트,웍스,서비스,몽고,통합',
#  '엔비디아,그래프,여개,연구,논문,발표,예고',
#  '클라우드,복권,수탁,사업자,선정,프라이,서비스,적용',
#  '엠로,기반,자재,가격,예측,분석,소프트웨어,출시',
#  '교육,플랫폼,코디,로봇,교구,추가',
#  '네이버,실적,발표,매출,기비,증가',
#  '스핀,글로벌,구글,클라우드,솔루션,데이,플래티넘,참가',
#  '이프,랜드,실사,기반,국내외,명소,오픈',
#  '미국,정부,암호,화폐,채굴,전력,세금,부과,법안,추진',
#  '리다,솔,시너지,소프트웨어,공개',
#  '네이버,클라우드,기업,브라우저,웨일,엔터프라이즈,베타,공개',
#  '카카오,사내,독립,법인,다음,설립',
#  '카카오,독립,기업,분리,다음,매출,하락,가장',
#  '카카오,독립,기업,분리,다음,매출,하락,가장',
#  '데이터,산업,직업',
#  '쿠팡,공간,색인,로켓,배송,개선,방법',
#  '다음,카카오,독립,기업,합병,분리',
#  '다음,카카오,독립,기업,합병,분리',
#  '취약점,사이버,격자,레지스트리,구성,오류,점,노출',
#  '챗,제작자,인류,파멸,초래,수도,인간,인지,능력,초월,가능성,언급',
#  '틸론,소프트캠프,클라우드,보안,사업,체결',
#  '엔비디아,고급,지원,시스템,상용',
#  '진원,컬처,확산,견인,신진,디자이너,브랜드,육성',
#  '정통부,올해,데이터,처,지원,투입',
#  '올해,실리콘,웨이퍼,하량,전분,기비',
#  '울산,이영,장관,미래,육성,예산,확대,협의',
#  '구글,픽셀,긱벤치,벤치마크,테스트,결과,공개',
#  '티맥스,메타,버스,기반,예술,대학,작품,전시',
#  '윤석열,정부,한국,경제,위기',
#  '구글,계정,패스,지원,발표',
#  '스핀,글로벌,스타,허브,통신업,디지털,전환,가속,체결',
#  '스테이지,라인,론칭,글로벌,시장,조준',
#  '트렌드,마이크로,글로벌,사이버,위험,지수,완화',
#  '뤼튼,대화,기능,이미지,무제한,무료,공개',
#  '카카오,실적,발표,매출,전분,기비,감소',
#  '일자리,습격,현실,비대,직무,대체,선언',
#  '연결,성과,보안,지능,개선,사례,프라이,의,이점',
#  '맥스,업데이트,론칭',
#  '해외,스타트업,인공,지능,얼굴,인기,가상,페르소나,조명',
#  '티맥스,메타,버스,국립,공주대,슈퍼,앱,기반,통한,체결',
#  '서치,출시,네이버,검색,운영,비용,테크,체인',
#  '서치,출시,네이버,검색,운영,비용,테크,체인',
#  '정통부,한계,도전,프로젝트,책임,공모',
#  '파수,보안,관리,매니,지드,서비스,론칭',
#  '컴파일러,컬렉션,신규,버전,배포,등,지원',
#  '서비스,유선,전화,패키지,상품,신규,출시',
#  '에이서,신제품,출격,한국,법인,설립,국내,시장,본격,공략',
#  '티맥스,티베로,서밋,서울,완전,관리,공개',
#  '탄소,지원,슈나이더,툴체인,공개',
#  '펜타시큐리티,암호,통합,관리,디아,컨트롤,센터,출시',
#  '한국,엡손,레이저,프로젝터,신제품,출시',
#  '국내,구진,온도,제어,반도체,패키징,문제,개선,기술,개발',
#  '엠로,자체,개발,기술,일본,특허,등록,결정',
#  '메타,버스,세상,나,공간,이프,도입',
#  '뇌출혈,영상,의료,솔루션,글로벌,논문,게재',
#  '진원,미래,콘텐츠,수출,마케터,육성',
#  '기부,지역,기업,혁신,공모,사업,과제,선정,발표',
#  '개념,장단점,솔루션,콘텐츠,서비스,플랫폼,모든',
#  '말레이시아,정부,화웨이,장비,압력',
#  '다른,유럽,미국,성형,규제,동향,시사',
#  '임원,억대,연봉,직무,가지',
#  '쿠버,티스,표준,아키텍처',
#  '기술,유출,범죄,솜방망이,처벌,특허청,대검찰청,세미나',
#  '소더비,체인,중고,마켓,레이스,출시,리움,폴리곤,토큰,결제,가능',
#  '브이,신진우,대학원,석좌교수',
#  '테크,스마트,무전,서비스,사업,확대,체결',
#  '나무,기술,농협,은행,은행원,서비스,칵테일,클라우드,공급',
#  '티맥스,티베로,완전,관리,소개',
#  '퀘스트,소프트웨어,코리아,클라우드,백업,보안,강조,디지털,대화,기여',
#  '배민,라이더,어린이날,파업,유력,당일,상황,예의,주시',
#  '배민,라이더,어린이날,파업,유력,당일,상황,예의,주시',
#  '코딩,트렌드,프로그래밍,언어,순위,발표,파이썬,인기,공개',
#  '이스트소프트,휴먼,사업,글로벌,확장',
#  '비보,고속,충전,스마트폰,네오,프로,출시,전망',
#  '주행,안정,강화,서비스로봇,업데이트',
#  '부산,국제,기계,대전,개최,스마트,팩토리,로봇,제조업,제시',
#  '로크,두산,전략,파트너,스마트,팩토리,기술,개발,협력',
#  '차세대,서비스,로봇,출시',
#  '반도체,디스플레이,급감,무역수지,적자',
#  '최태원,경제,외교,지원,수소,그린,비즈니스,집중',
#  '사이버,레이,방화벽,평가,등급,획득',
#  '전자,구글,남양주,부평,초등학교,미래,교실,조성',
#  '나스닥,상장,예고,최대,빅뱅',
#  '게이츠,재단,지원,감염병,대응,연구,마무리,관련,데이터,일반,공개',
#  '스테이지,생명,금융,솔루션,공급',
#  '폴리곤,프로토콜,성장,가속,지원',
#  '팹리스,스타트업,기반,가속,개발',
#  '주식,투자,스팸,발생',
#  '정통부,디지털,국정,과제,현장,간담,종합,토론회,개최',
#  '머신,러닝,모델',
#  '넷마블,테크니컬,라이터,개월,회고',
#  '체지방,바로,분석,완료,체형,측정,시스템,기반,수트,등장',
#  '한국,국내,시장,평균,성장,기대',
#  '유아,패스,공식,앱,자동화,플랫폼,제공',
#  '스켈터랩스,챗봇,솔루션,신규,출시',
#  '부산,은행,기업,뱅킹,비대,채널,개편,시스템,구축',
#  '네트웍,통합,애플리케이션,딜리,솔루션,출시',
#  '공공기관,오픈소스,활용,확대,지원',
#  '기업,사이버,복원력,확보',
#  '마이크로,디스플레이,버전,애플,워치,울트라,하반기,출시,가능성,제기',
#  '챗봇,민원,신고,링크,바로,연결,비즈니스,출시',
#  '애플,아이폰,출시,앞서,버전,유선,이어폰,준비',
#  '케이,던스,하이닉스,모바일,램,상호,운용,검증',
#  '마이크로,닉스,맥스,파워서플라이,출시',
#  '뤼튼,일본,진출,공식,영어권,생태계,확장',
#  '이즈,다우기술,기업,솔루션,알리,공급',
#  '스테이지,생명,금융,특화,솔루션,공급',
#  '팀뷰어,차세대,원격,액세스,솔루션,모트,출시',
#  '가트너,올해,전세계,반도체,매출,감소,전망',
#  '국토부,기업,혁신,파크,추진,주도,지방시',
#  '보쉬,미국,인수,전기차,시장,공략',
#  '글로벌,칼럼,은행,대체,애플,질주',
#  '플러터,다른,크로스,플랫폼,이유',
#  '미드,레벨,엔지니어,가지,역량',
#  '이제,챗,영어,교과,공부,소프트,초등,솔루션,알공,도입',
#  '부장,스타트업,기부,품목,국산,지원,개사,신규,선정',
#  '카카오,제주,개발,공사,해양,플라스틱,자원,순환,추진',
#  '삼성,실적,발표,매출,영업',
#  '엔비디아,오픈소스,네모,가드레일,출시',
#  '대웅제약,포스,업무,프로세스,고도화',
#  '산업부,스마트,스타트,우수,바이오,기업,투자,설명,개최',
#  '삼성,가전,전시회,마이크로,공개',
#  '애플,벤투라,퍼블릭,베타,버전,배포',
#  '친환경,소재,제품,포장,전면,변경',
#  '스핀,글로벌,클라우드,네이티,보안,컨퍼런스,개최',
#  '골프,플랫폼,기술,접목,손',
#  '스마트,기기,통합,표준,조사,협력,대중화,열쇠',
#  '다시,엔지니어링,집중,인텔,싱어,리더십,중간,평가',
#  '디지털,트윈,개발,착수,반드시,단계',
#  '매출,상승,부문,클라우드,오피스,서버',
#  '챗,시작,불과,수면,위로,챗봇,안보,위협',
#  '세계,반도체,매출,감소,전망,가트너',
#  '연간,블루투스,기기,하량,전망',
#  '쿠버,티스,관리,방법',
#  '반도체,디스플레이,외국인,투자,최대,보조금,지원',
#  '루닛,인디카,랩스,파트너쉽,스코프,유통,채널,확대',
#  '몸,착용,인공,지능,비서,스타트업,웨어,러블,어시스턴트,개발',
#  '함샤우트,글로벌,홍보,업계,최초,업무,혁신,위,챗,경진,대회,개최',
#  '한국어,기술,지원,서비스,개시',
#  '이니텍,렉스,전자,문서,서비스,물류,체계,구축,협력',
#  '오페라,개선,브라우저,초기,버전,배포',
#  '기부,미국,뉴욕,글로벌,비즈니스,센터',
#  '스노우플레이크,한국,타이어,통합,데이터,분석,플랫폼,구축',
#  '의약품,연구,양자,컴퓨팅,생,성형,활용,모색',
#  '쿠도,커뮤니케이션,아이,계약,체결',
#  '게임,콘솔,칩셋,라이,시리즈,공개',
#  '올리브,네트웍,딜,라이브,서비스,구축',
#  '기반,이음,지능,관제,솔루션,상용',
#  '칠레,수소,협력,세미나,개최,그린,파트너,강화',
#  '데이터,브릭스,국내,오프라인,행사,오픈소스,모델,공개',
#  '하이닉스,실적,발표,영업,손실,적자,전환',
#  '의장,생각,상용,지체,시간',
#  '몸값,자체',
#  '디지털,서비스,인터넷,거물,규제,나선',
#  '데이터,주도,프로,덕트,개발,실험,환경',
#  '슈나이더,헝가리,나베체,친환경,스마트,공장',
#  '클라우드,테크,중소기업,대상,금융,지원,사업,참여',
#  '스패,로우,중소기업,클라우드,서비스,보급,확산,사업,공급,기업,선정',
#  '루스,첨단,소재,실적,발표,영업,손실,기록',
#  '세대,클로이,적용,서빙,로봇,서비스,론칭',
#  '한국,양성평등,교육,진흥,행안부,클라우드,전환,성공사례,선정',
#  '지멘스,제조,산업,컴피턴시,획득',
#  '프론,테오,코리아,디지털,포렌식,솔루션,키빗,재미,출시',
#  '블럭,애플리케이션,최적화,모듈,출시',
#  '씨게이트,재생에너지,전환,드라이브,순환,프로그램,탄소,중립,가속',
#  '슈나이더,트릭,헝가리,나베체,스마트,공장,신설',
#  '티맥스,티베로,클라우드,집중,공략,결실,최대,매출,기록',
#  '틸론,제주,도민,체전,메타,버스,플랫폼,구축',
#  '스핀,글로벌,사이버,보안,기여,공로,한국,정보보호,학회,감사패,수여',
#  '유플러스,신형,클로이,서빙,로봇,출시',
#  '코오롱,니트,디앤,한라,스마트홈,플랫폼,개발,사업,수주',
#  '중고,코딩,교육,활성화',
#  '리소그래피,지원,베리,공개',
#  '개발,스캐터랩,분투',
#  '글로벌,칼럼,애플,준비',
#  '네트워크,연결,기계,안정,필수,유럽연합,장비,규제,채택',
#  '클라우드,비용,최적화,수백만,달러,절약,쿠팡,노력',
#  '당신,이유',
#  '정통부,정보보호,공시,의무,기업,발표,년비,개사,증가',
#  '워싱턴포스트,시스템,훈련,데이터,세트,파시스트,성향,악성,콘텐츠,포함',
#  '주파수,커버,리지,확장,기술,실증,성공',
#  '카카오,모빌리티,현대,글로비스,물류,공급망,개발,체결',
#  '웨인,힐스,음성,영상,변환,서비스,에디슨,어워드,동상,수상',
#  '화물,중개,운송,플랫폼,브로,캐리,업데이트',
#  '최신,인텔,세대,프로세서,지포스,시리즈,탑재,크리에이터,노트북,출시',
#  '알서포트,모트,미팅,챗,회의,자동,요약',
#  '타인,에이,아이,기반,애널,리스트,서비스,출시',
#  '네이버,동네,공원,리뷰',
#  '네이버,동네,공원,리뷰',
#  '코딩,트렌드,러스트,인기,프로그래밍,언어,랭킹,티,지수,순위',
#  '네이버,웨일,폴라리스,오피스,웹,연동,개시',
#  '에이수스,크리에이터,노트북,출시',
#  '지멘스,로,산업,생산',
#  '프론,테오,코리아,차세대,디지털,포렌식,솔루션,키빗,재미,출시',
#  '스테이지,국제,경진,대회,부문,석권,아마존,엔비디아',
#  '테크,참전,확대,글로벌,패권,누구',
#  '나노,라이,임베디드,프로세서,출시',
#  '직원,경험,플랫폼,비바,비서,파일럿,탑재',
#  '산업,무선,네트워크,솔루션,시리즈,출시',
#  '글로벌,이커머스,앱,다운로드,건,전망,중국,성장,주목',
#  '글로벌,칼럼,베이,결과,이유',
#  '로그,프레,비즈니스',
#  '정통부,진흥,전략,발표,국민,디지털,역량',
#  '머신,러닝',
#  '소니코리아,증강현실,앱,스노우,협업,무선,노이즈,슬링,헤드폰,필터,론칭',
#  '부터,디지털,트윈,전문가,미래,자동차,제조,시설,풍경',
#  '우리,회사,최고,재무,책임자,기업,챗,알파,테스트,버전,배포',
#  '디지털,생산,성의,발견,선택,필수',
#  '그룹,디지털,전환,역량,시행',
#  '이익,배민,자회사,청년,수익,개선,묘연',
#  '이익,배민,자회사,청년,수익,개선,묘연',
#  '올해,전세계,퍼블릭,클라우드,시장,달러,육박',
#  '코딩,트렌드,오브,젝티브,인기,프로그래밍,언어,랭킹,티,지수,순위',
#  '커넥티드,의료,기업,고려,핵심,요소',
#  '전자,오픈소스,보안,관리,프로세스,역량',
#  '스핀오프,기업,로,스마트폰,조작,마우스피스,개발',
#  '하이닉스,적층,개발,상반기,양산,준비,완료',
#  '클라우드,비용,절감,방안,제시',
#  '통운,이천,풀필먼트센터,국내,최초,이음,도입',
#  '파수,기업,출시,예고,로,보안,강화',
#  '에이서,넥스트,통해,노트북,신제품,대거,공개',
#  '직원,유지,기업,전하,하이브리드,근무,운영',
#  '주니어,웹,개발자,동기,통신',
#  '자바스크립트,자리,창시자,인터뷰',
#  '랜섬,웨어,사이버,스파이,활동',
#  '철도공사,국전,금융,교통,분야,오스,플랫폼,구축',
#  '팀뷰어,디지털,제조,솔루션,프론트라,통합',
#  '가장,두뇌,제한,대화,네이티,기능,전면,무료,제공',
#  '유,블럭,호스트,기반,모듈,글로벌,유통,개시',
#  '파수,한국,항공대,체결,인재,양성',
#  '엑스,로그,장석주,매출,데이터,통합,관리,솔루션,경쟁력,입증',
#  '코딩,트렌드,스위프트,인기,프로그래밍,언어,랭킹,티,지수,순위',
#  '기업,영진,과반,회복,탄력성,부족,인식',
#  '영림,소프트,신흥,정밀,그룹,라이선스,공급',
#  '이노,그리드,확산,서비스,소프트웨어,기술,개발,사업,수주',
#  '퀀팃,기반,금융,자산,관리,콘텐츠,공급,협력',
#  '서울대,병원,영유,자폐,스펙트럼,장애,조기,진단',
#  '정통부,이음,실증,사업,공모,제조,물류,개,과제,대상',
#  '디지털,생태계,위험,가지,실수,대책',
#  '공개,실행,엔진,독점,제조,시스템,도전',
#  '한국,비즈니스,리더,의사결정,오라클',
#  '유럽,제조,역량,중점,반도체,법안,합의',
#  '세계,퍼블릭,클라우드,지출,대비,증가,가트너,전망',
#  '초보,개발자,완전,기초,지식,이론',
#  '네이버,원쁠딜,뉴려,원,아이디어',
#  '네이버,원쁠딜,뉴려,원,아이디어',
#  '디스플레이,회복,옴,디아,가동,로,반등',
#  '올리브,네트웍,월드,홀로그램,기술,공개',
#  '에프원,시큐리티,웹,캐슬,정보보호,신속,확인,통과',
#  '구글,개발자,컨퍼런스,더블,폰,픽셀,폴드,공개,예고',
#  '코딩,트렌드,타입,스크립트,인기,프로그래밍,언어,랭킹,티,지수,순위',
#  '챗,플러그인,결합,최신,정보,반영,기대',
#  '슈나이더,트릭,케이엠,파워,월드,핵심,제품,선봬',
#  '팀뷰어,디지털,제조,솔루션,통합,생산',
#  '스핀,글로벌,헬프,나우,챗봇,옵스,적용',
#  '클라우드,지코,글로벌,시장,사업,확장,체결',
#  '컴투,버스,실제,가상,오피스,비주,영상,글로벌,공개',
#  '엔비디아,프레이,가상,공장,데모,위해,지멘스,협업',
#  '샤오미,카메라,탑재,스마트폰,울트라,공개',
#  '샤오미,태블릿,신제품,패드,시리즈,공개',
#  '그렉,브록먼,머신,러닝,전문가',
#  '프로,삼성,화소,아이,카메라,센서,탑재,가능성,제기',
#  '뉴스,구독,서비스,정식,오픈',
#  '네이버,제트,또,메타,버스,플랫폼,크래프톤',
#  '네이버,제트,또,메타,버스,플랫폼,크래프톤',
#  '대기업,퇴직,전문가,스마트,공장,구축,운영,지원',
#  '로우,코드,전문,인력,구세주',
#  '스튜디오,토에이,애니메이션,글로벌,시장,공략,확대',
#  '삼성,오픈소스,프로젝트,헬스,스택,선공',
#  '시스,라이,개최,자율,주행,시뮬레이션,관련,최신,기술,산업,동향,공유',
#  '기반,챗봇,어시스턴트,구축,개발자,세계,대세,우뚝,외신,주목,앱',
#  '코딩,트렌드,인기,프로그래밍,언어,랭킹,티,지수,순위',
#  '블루,프리즘,인증,획득,품질,우수,입증',
#  '크레프,네이버,제트,합작,법인,설립,미글루,연내,출시,목표',
#  '씨게이트,아이언,울프,프로,출시',
#  '화웨이,배터리,탑재,스마트폰,엔조이,출시',
#  '구글,클라우드,준,신임,코리아,사장,선임',
#  '마이크로,닉스,글로벌,시스,전시회',
#  '에이,디자인,어워드,본상,연속,수상',
#  '에이서,신설,한국,법인,대표,웨인,선임',
#  '클라우드,개정,금융,가이드라인,고려,사항,주제,웨비,개최',
#  '컴투,버스,바스,메타,관련,기술,사업,협력,협약',
#  '로보티,독일,하노버,산업,박람회,차세대,로봇,액츄에이터,공개',
#  '나무,기술,규모,멀티,클라우드,관리,플랫폼,개발,사업,참여',
#  '엑스,옥,디어,버추,프로덕션,협력,시동',
#  '갤럭시,검색,엔진,소식,구글,패닉',
#  '정부,디지털,플랫폼,기반,정통부,사업,설명',
#  '스크,롤링,효과,대처,방법',
#  '뤼튼,플러그인,플랫폼,출시',
#  '국내,구진,금속,나노,촉매,고체,산화물,연료,전지,성능',
#  '네이버,골프,커뮤니티,주목,이유',
#  '네이버,골프,커뮤니티,주목,이유',
#  '카카오,하이브,협업,개시,버스,엔터,커뮤니티,오픈',
#  '진원,애니메이션,협회,애니,프로듀서,양성,협력',
#  '이노,그리드,지난해,수주,잔고,확보',
#  '수신,기술,시연',
#  '코딩,트렌드,인기,프로그래밍,언어,랭킹,티,지수,순위',
#  '협력,나선,소통,강화,우려,해소',
#  '블루,프리즘,지능,자동화,솔루션,인증,획득',
#  '국내,서버,시장,향후,평균,성장',
#  '근무,장기,영향,매사추세츠주,시범,사업,추진',
#  '충전,지구,청정,에너지,이용,지능,가능성',
#  '씨게이트,손,엣지,클라우드,스토리,통합,솔루션,발표',
#  '국토부,밀양,나노,융합,국가,스마트,그린,지정',
#  '하시코프,아몬,데드,클라우드,도입,핵심,요소,제로,트러스트,보안',
#  '산업부,소비자,단체,제품안전,간담,개최',
#  '커밋,메시지,컨벤션',
#  '동의대,연구,센터,인재,양성,대전,부산,로봇,공개',
#  '에이,블리,지난해,매출,껑충',
#  '에이,블리,지난해,매출,껑충',
#  '소프트웨어,기업,오픈소스,대규모,언어,모델,공개',
#  '코오롱,니트,라우,파트너,멘토,프로그램,확대',
#  '제품,수명,주기,보안,업데이트,임베디드,큐어,기능',
#  '데이터,기반,미래,혁신,서비스,발굴',
#  '지난해,반도체,장비,매출,사상,최대,유럽,년비',
#  '코딩,트렌드,인기,프로그래밍,언어,랭킹,티,지수,순위',
#  '미래,보안,사람,중심,기술,운영,방식,구성,핵심',
#  '이노,디스크,중심,개발,전략,발표,생태계,구축,강조',
#  '샤오미,출시,태블릿,퀄컴,칩셋,채택,예고',
#  '창립,주년,로고,슬로건,공개',
#  '해외,애널,리스트,구글,플래그,스마트폰,픽셀,시리즈,스펙,전망,공개',
#  '마이크로,닉스,지포스,베르토,그래픽카드,출시',
#  '비트디펜더,엔드,포인트,보안,카테고리,선정',
#  '티맥스소프트,한국,역정보,개발,차세대,클라우드,운영,협력',
#  '카카오,브레인,김일,대표,직원,스톡옵션',
#  '카카오,브레인,김일,대표,직원,스톡옵션',
#  '알파,지니,뮤직,홈쇼핑,창작',
#  '로그,프레,양봉,클라우드,기업,전환,점유,확대',
#  '정통부,혁신,수상,기업,오찬,건의,사항,조치,결과,공유',
#  '글로벌,칼럼,마이크로소프트,겨누,각국,정부,과거,반복',
#  '스카이,자비스,한끗,차이,스톤,기반,요소',
#  '소비재,기업,지속,경영,위해,기술,예산,포럼',
#  '전문가,최신,엔터프라이즈,기술,랜드,가지',
#  '쿠팡,기계학습,물류,프로세스,개선,방법',
#  '택슬리,챗,도입,챗봇,서비스,출시',
#  '리멤버,매출,적자,증가',
#  '리멤버,매출,적자,증가',
#  '공용,충전기,사용,사이버공격,위험성,경고',
#  '외국,지식인,챗봇,명령어,입력,기반,생,기능,추가,코딩,지식,이상',
#  '국토부,혁신,기술,공모,사업,민간,발굴,도입',
#  '퍼즐,데이터,프로세스,인텔리전스,플랫폼,시장,개척',
#  '로그,프레,클라우드,기업,발표',
#  '구글,안드로이드,베타,버전,배포',
#  '광양시,구축,여개,주요,도로,솔루션,적용',
#  '코딩,트렌드,인기,프로그래밍,언어,랭킹,티,지수,순위',
#  '모바일,인텔,공정,지원,기술,협력,발표',
#  '노르딕,세대,멀티,프로토콜,시리즈,공개',
#  '개발,후반,보안,기능,추가,가능,임베디드,큐어,출시',
#  '마이크로,닉스,케이스,출시',
#  '브랜드,벤트,선언,전자,지역,세대,초월,변화,추진',
#  '해외,애널,리스트,애플,자체,설계,모뎀,탑재,아이폰,출시',
#  '스파르타,코딩,클럽,챗,기반,튜터,서비스,론칭',
#  '포스,태블,아인슈타인,연동',
#  '한쪽,정리해고,다른,쪽선,구인,채용,시장,풍경',
#  '글로벌,모바일,게임,수익,달러,돌파,전망,센서,타워',
#  '개발자,보안,정복,악성코드,대응',
#  '투자,관리,앱,미노,챗,기반,실적,요약,출시,발표,핵심',
#  '물리,기술,보안,모두,중요,삼성,국제,표준,시스템,강조',
#  '알리바바,클라우드,인텔리전스,모델,이치,공개',
#  '티맥스,기반,물류,혁신,솔루션,개발,본격',
#  '산업,영상,관제,시스템,현장,테스트,수도권,영차,적용',
#  '한국,아태,지역,이슈,발표,지속가능성,논의,공론,전망',
#  '틱톡,피드,해외,테크,플랫폼,영상,디지털,자산,전환,기능,공개',
#  '코딩,트렌드,자바스크립트,인기,프로그래밍,언어,랭킹,티,지수,순위',
#  '패스,기반,소재,공정,기술,개발,완료',
#  '궈밍치,애플,인치,미니,디스플레이,출시,계획',
#  '현장,인재,육성,펠로우,지원,모집',
#  '무하,사람인,서류,평가,서비스,프리즘,제공',
#  '카카오,미디어,자문,기구,뉴스,투명,위원회,확대,개편',
#  '유플러스,코리아,버스,출시,기념,이벤트,진행',
#  '국토부,지자체,공간,정보,우수,사업,충북도,경기,성남,인천,동구,최종,선정',
#  '몽고,동화,기업,스마트,생산,시스템,구축,지원',
#  '하량,급감,캐널,라이스',
#  '글로벌,칼럼,프라이,업종',
#  '올해,미래,핵심,문화,트렌드,메타,보고서,공개',
#  '프론트엔드,개발자,이유',
#  '알리바바,클라우드,대규모,모델,치안,공개',
#  '정전기,초미세먼지,기계,무,필터,공기,청정,기술,개발',
#  '공정위,리니지,독점,구글,과징금,철퇴,유감',
#  '공정위,리니지,독점,구글,과징금,철퇴,유감',
#  '슈나이더,능동,필터,로직,공개',
#  '인증,획득,기업,네이버,클라우드',
#  '네이버,클라우드,매출,돌파',
#  '네이버,클라우드,매출,돌파',
#  '반도체,특허,심사,추진단,공식,출범',
#  '티맥스소프트,웨어,일본,시장,공략,강화',
#  '분석,기술,적용,이메일,보안,솔루션,상용',
#  '마이크로,닉스,글로벌,시스,전자전,참가',
#  '코딩,트렌드,자바,인기,프로그래밍,언어,랭킹,티,지수,순위',
#  '스노우플레이크,데이터,클라우드,기초,워크숍',
#  '산업부,삼성,무료,기술,나눔,특허,공개',
#  '슈나이더,트릭,코리아,능동,필터,로직,출시',
#  '챗,포문,생,시장,국내,빅테크,도전',
#  '전자,세대,클로이,서브,월드,첫,공개',
#  '아시아,메타,버스,컨퍼런스,개막',
#  '포스,기반,산업,특화,개발',
#  '수,전성기,기계번역,가능성,한계',
#  '디지털,소비자,서비스,시장,달러,규모,성장,디아',
#  '한국,지속,투자,전략,아태,지역,전망,발표',
#  '해외,스타트업,성형,기반,오디오,광고,제작,자동화,플랫폼,선봬,스크립트,작성,음성,추가,지원',
#  '스핀,글로벌,클라우드,비용,절감,무료,컨설팅,캠페인,진행',
#  '부산,방문,이인실,특허청장,예비,창업,목소리,소통',
#  '빅스,글래스,수출,기업,환경,규제,대응,지원',
#  '니드,폴란드,국영,연구소,산업,재해,로봇,개발',
#  '코딩,트렌드,파이썬,인기,프로그래밍,언어,랭킹,베,지수,순위',
#  '자율이동,로봇,자동화,분야,주목,기술,트렌드',
#  '마이크로,닉스,맥스,포커스,시리즈,포토,후기,이벤트,실시',
#  '택배,론칭,네이버,물류,지원,강화',
#  '애플,에어팟,청취,경험,몰입,특허,출원',
#  '윈드,리버,기업,인증,획득',
#  '민관,협력,전자정부,개발,표준,프레임워크,개선',
#  '챗,로봇산업,융합,기대,휴머노이드',
#  '미국,정부,칩스,장애물,청사진',
#  '블랙박스,비즈니스,가치,측정,단계',
#  '가트너,세계,지출,예상,상향,조정,서비스,강세,성장',
#  '나노,탑재,압축,효율,최적화,가속,공개',
#  '콘텐츠,기업,기술,특례,상장,모습,티빙',
#  '콘텐츠,기업,기술,특례,상장,모습,티빙',
#  '인,피니언,글로벌,유통,시작',
#  '소화기,학회,의료,연구',
#  '인공,지능,팩토리,마이크로소프트,챗,애저,개최',
#  '테스트,코드',
#  '웹,그래픽,크롬,복수,브라우저,지원',
#  '기업,전문의,글래스,공개,양치,환자',
#  '코어,월랫,랜드,연동,수집,기능,포함,대형,업데이트,예고,진행',
#  '아동,청소년,게임,행동,실태,조사,이용',
#  '네이버,브랜드,커넥트,스마트,스토어,적용,확대,창작,협업,지원',
#  '클라우드,김해,센터,지역,생태계,활성화',
#  '엔씨,디지텍,갤럭시,블로썸,학기,프로모션,실시',
#  '로그,프레,규모,시리즈,투자,유치,성공',
#  '플랫폼,베이스,무전,디지털,서비스,론칭',
#  '코딩,트렌드,비주,베이직,인기,프로그래밍,언어,랭킹,티,지수,순위',
#  '차량,구매,발,카카오,트럭,택시',
#  '차량,구매,발,카카오,트럭,택시',
#  '신뢰,동료,기업',
#  '케미칼,자회사,여수,공장,준공,친환경,접착제,생산,본격',
#  '이노,그리드,효성,인포,메이,시스템,클라우드,사업,협력,협약,체결',
#  '로보티,국회,정부,관계자,자율,주행,로봇,사업,모델,소개',
#  '미코,반도체,공정,펄스,히터,출시,시장,공략,본격',
#  '고립,가구,안전,구축,금천구청,안부,서비스,체결',
#  '글로벌,칼럼,개발,일시,중단,생각,이유',
#  '넘버스,일터,가지,장면',
#  '네이버,스마트,스토어,플루,홍보',
#  '네이버,스마트,스토어,플루,홍보',
#  '선사,성형,인류,사회,혼란,원흉,전락',
#  '정통부,강소,특구,기술이전,릴레이,설명,연',
#  '레트라,기반,스토리,서비스,론칭',
#  '보이스,콘텐츠,제작,플랫폼,망고,보드,적용',
#  '기업,사이버,범죄,조직,운영,임금,지불',
#  '해외,연구,챗,라이벌,바드,거짓,정보,혐오,발언,위험성,심각,경고',
#  '코딩,트렌드,루아,인기,프로그래밍,언어,랭킹,티,지수,순위',
#  '삼성,라데온,그래픽,엑시노스,확대,적용',
#  '효성,인포,메이,파트너,비즈니스,협력,모델,구축,적극,지원',
#  '조사,양자암호,통신망,통합,기술,개발,실증,완료',
#  '나임,네트웍,탱고,글로벌,방송,아시아,대표,제품,소개',
#  '창립,주년,기술,선구자,달성,박차',
#  '스테이지,추천,시리즈,출시',
#  '보이스,망고,보드',
#  '유플러스,우리카드,고객,센터,음성,제공',
#  '한국,후지필름,보안,솔루션,앱,가드,출시',
#  '정부,반도체,배터리,핵심,기술,투입,격차,확보',
#  '산업부,국가,핵심,기술,고시,개정,공포,수소,분야,신설',
#  '뉴,로티,알,머신,격차,실현',
#  '주목,테크,트렌드,한국,딜로이트,그룹',
#  '암호,화폐,프리,민팅,피싱,메일,발견,주의보',
#  '케이,스마,클라우드,획득',
#  '틸론,메타,버스,플랫폼,풀브라우징,핵심,가상화,통해,기여',
#  '기계,함정,손상,평가,모델링,기술,넥스,기술이전',
#  '테크,지스,기업,클라이언트,신제품,공개',
#  '정통부,메타,버스,노마드,지원,사업,운영,기관,공모',
#  '진원,국내,플랫폼,개사,콘텐츠,유통,활성화',
#  '전문,성우,게임,캐릭터,음성,구현,회의,목소리,불안감',
#  '버티브,분산,네트워크,단상,리버,출시',
#  '파수,랩소디,클라우드,시장,공략,강화',
#  '드론,비행,관련,국제,표준,제정',
#  '도입,확대,각국,정부,규제,논의,확산,이탈리아,챗,사용,금지',
#  '팀뷰어,아태,지역,신규,파트너,프로그램,팀업,발표',
#  '코딩,트렌드,스칼라,인기,프로그래밍,언어,랭킹,티,지수,순위',
#  '특허청,반도체,전담,심사,신설,제조,소재,장비,분야',
#  '삼성,전자,팔방미인,스마트,모니터,신제품,출시',
#  '지멘스,다임러,트럭,통합,디지털,엔지니어링,플랫폼,구축',
#  '아이티,분산,클라우드,서비스,전문,컨설팅,론칭',
#  '마이크로,닉스,글로벌,시스,컨슈머,전자전,참가',
#  '한국,오라클,서울,창업,허브,창동,스타트업,제공',
#  '아이폰,지원,대상,제외,가능성,관측',
#  '크로스,네이버,클라우드,광고,마케팅,법률,개발',
#  '코리아,넥스트,클라우드,아카데미,모집',
#  '인공,일반,지능,마주,결심,감치,대응,거나',
#  '탄소,배출,데이터,센터,기후,변화,해결,중심,기능',
#  '미국,인구,커버,아마존,무료,네트워크,사이드',
#  '개발자,보안,정복,침해,사고,분석',
#  '개발자,보안,정복,침해,사고,분석',
#  '코드,리뷰,개발,문화,영향',
#  '코드,리뷰,개발,문화,영향',
#  '진원,콘텐츠,기업,지원,센터,조성,사업자,부산시,컨소시엄,선정',
#  '연구,모래밭,잔디,드리블,사족,보행,로봇,공개',
#  '티맥스소프트,실적,발표,매출,영업,달성',
#  '카카오,앱,전기차,구매,상담,글로벌',
#  '카카오,앱,전기차,구매,상담,글로벌',
#  '스테이지,챗봇,애스크,이미지,기능,추가',
#  '젯브레인스,자바,자바스크립트,루비,개발,업그레이드,버전,배포',
#  '분사,클라우드,매출,영업,달성',
#  '틸론,인공,지능,기반,메타,커머스,사업,추진',
#  '프론,테오,코리아,기반,협업,감사,솔루션,출시',
#  '버티브,분산,네트워크,에지,컴퓨팅,앱용,단상,출시',
#  '삼성,고객,전용,스토어,서비스,전세계,개국,확대',
#  '코딩,트렌드,다트,인기,프로그래밍,언어,랭킹,티,지수,순위',
#  '제조,기업,특화,클라우드,엔지니어링,플랫폼,론칭',
#  '기부,플래닛,청소년,앱,개발,대회,스마,린지,개최',
#  '비보,플립,중국,유출,삼성,갤플,견제',
#  '구글,안드로이드,바이,셰어,윈도,베타,버전,배포',
#  '그것,보안사,첫걸음,사이버,하이',
#  '유명,애널,리스트,프로모션,아이폰,기본,모델,확대,적용',
#  '방통위,단말기,유통,위반,과징금,경감,사유,구체화',
#  '로보티,바스,자율,주행,로봇,고도화,위해,협력',
#  '대학,전용,메타,버스,플랫폼,출시',
#  '에이서,게이,노트북,프레데터,헬리오스,네오,신제품,출시',
#  '규제,대응,슈나이더,코스,트럭,로,해운업,공략,본격',
#  '정통부,챗,기본,원리,부내,교육,실시',
#  '초보자,코딩,디토,랜드,비주,스크립트,에디터,공개',
#  '스테이지,챗봇,이미지,기능,추가,현재,베타,서비스',
#  '마이크로소프트,제조,혁신',
#  '주니어,개발자,계층,이야기',
#  '주니어,개발자,계층,이야기',
#  '올림플래닛,한국,산업,단지,공단,가상공간,구축',
#  '온라인,배당,조회,서비스,오픈,환경보호,강화,취지',
#  '최민,교수,친환경,분리,공정,원천,기술,개발',
#  '네이버,직원,스톡,그랜트,쏜다',
#  '네이버,직원,스톡,그랜트,쏜다',
#  '삼성,인증,획득,프로세스,품질,역량,입증',
#  '코오롱,니트,스틸,컨버전,프로젝트,완료',
#  '프론,테오,코리아,협업,부정행위,방지,솔루션,키빗,아이,출시',
#  '세미,배런스,지속,미국,기업,선정',
#  '코딩,트렌드,비주,베이직,애플리케이션,인기,프로그래밍,언어,랭킹,티,지수,순위,밖',
#  '제로,싱크,블록,스트림,우주,비트코인,지식,증명,지원',
#  '마이,리얼,트립,패키지,여행,시장,노크',
#  '마이,리얼,트립,패키지,여행,시장,노크',
#  '슈나이더,트릭,선박,에너지,절감,전력,관리,솔루션,제안',
#  '옥타,도입,암호,화로,보안,강화',
#  '특허청,애플,슈팅,게임,컨트롤러,특허,공개',
#  '스테이지,이미지,기능,베타,서비스,오픈',
#  '클라우드,기술,유닛,체제,신설,통해,성장,가속',
#  '클라우드,기반,고성능,엔지니어링,플랫폼,서비스,출시',
#  '사용,쇼핑,앱,악성,발견,전례',
#  '네이버,웨일,아피스,제휴,스페이스,쏠북',
#  '딥노,이드,가톨릭,의대,동문회,의료,사업',
#  '용인,트레이닝,센터,반도체,전문,인력,육성',
#  '진흥,개정안,국회,통과,영향,평가,제도,강화',
#  '배달,민족,흑자,앱,타개',
#  '배달,민족,흑자,앱,타개',
#  '인공,지능,산업,융합,사업,수집,데이터,최초,개방,창업,활성화,목적',
#  '솔트룩스,한국판,챗,루시아,최초,공개,금융,대상,세미나',
#  '프로젝트,엑소,브레인,완료,특허,출원',
#  '정보보호,산업,일부,개정,법률,국회,통과',
#  '진원,콘텐츠,한국,경제,게임,체인,성과,보고,료',
#  '우분투,프로,프라,이스,오픈소스,채택,문제,구세주,등장',
#  '카카오,모빌리티,개편,앱,통합,검색',
#  '카카오,모빌리티,개편,앱,통합,검색',
#  '피싱,메일,탐지,챗봇,방해,사이버,보안,전문가,경고',
#  '코딩,트렌드,에이,인기,프로그래밍,언어,랭킹,티,지수,순위',
#  '인티,리트,데이터,챗,지원,대화,로봇,출시',
#  '글로벌,기업,과반,자동화,지속가능성,준비',
#  '휴먼,체결,인공,지능,영업,인간,특성',
#  '올리브,네트웍,차세대,스튜디오,구축',
#  '네이버,사우디,정부,기관,프로젝트,협력',
#  '국내,기업,이후,투자,크게',
#  '인성,정보,지난해,매출,돌파,성장,동력,확보',
#  '하시코프,인프라,자동화,솔루션,공급',
#  '미드,저니,이미지,통한,가짜,뉴스,확산,무료,평가판,일시,중단',
#  '쿠버,티스,환경,대표,보안,기능,가지',
#  '쿠버,티스,환경,대표,보안,기능,가지',
#  '게임,분야,혁신,리니지,아버지,토크쇼,개최',
#  '전직,개발자,다음,등장,세계,날,얼마,남지,주장',
#  '에이트,기술,특례,상장,본격,평가,등급,획득',
#  '북도,기반,메타,버스,실증,본격',
#  '노르딕,아마존,사이드,애플리케이션,지원,확대',
#  '바스,음성,지능,기반,디지털,트윈,영역,확대',
#  '파블로,항공,몽골,기업,블루몬,현지,드론,배송,협력,체결',
#  '한컴,네이버,클라우드,파트너,한컴오피스,초대,규모,통합',
#  '맞춤,광고,챗봇,챗,반응,게재,방안,실험',
#  '코딩,트렌드,루비,인기,프로그래밍,언어,랭킹,티,지수,순위',
#  '데이터,저장,관리,환경오염,유발',
#  '로옴,소형,모터,구동,최적화,시리즈,개발',
#  '아이폰,프로,배터리,방전,버튼,특정,기능,작동,지원,하나',
#  '하시코프,테스트,베드,셀프서비스,자동화,구축',
#  '정통부,지역,산업,융합,생태계,조성,확대',
#  '사이버,보안,로,시큐리티,파일럿,공개',
#  '나무,기술,규모,정부,사업,참가,생태계,확대,탄력',
#  '인천,제청,시설,공단,송도,동구,디지털,관리,시스템,구축',
#  '그룹,시스템,재해,복구,체계',
#  '사이버,보안,운영,정책,수립,고려,강화,인적,요소',
#  '명현,교수,보행,로봇,제어,기술,드림,워커,개발',
#  '데이터,책임자,설문조사,어려움',
#  '실전,활용,본격,컨퍼런스',
#  '컴퓨팅,사고,개발,실력,공부',
#  '컴퓨팅,사고,개발,실력,공부',
#  '구글,광고,투명,센터,이유',
#  '구글,광고,투명,센터,이유',
#  '라이브,사업,제휴,수도권,광고,커버,리지,확대',
#  '규제,샌드박스,심의,건,특례,지정',
#  '신입,공개,채용,나선,네이버,별,맞춤,전형',
#  '신입,공개,채용,나선,네이버,별,맞춤,전형',
#  '머스크,전문가,시스템,훈련,중단,촉구',
#  '포스,산나,이스,클라우드,공급,프로젝트,지원',
#  '카카오,먹통,피해,구체,공개,하라,민원,내용,법안,발의',
#  '카카오,먹통,피해,구체,공개,하라,민원,내용,법안,발의',
#  '명문,교수,진행,비즈니스,프로젝트,실험,인간,능력,입증',
#  '영림,소프트,탑,구축,프로젝트,완료',
#  '시큐리티,파일럿,공개,보안,차세대,도입',
#  '한컴,네이버,클라우드,교육,시장,공략',
#  '코딩,트렌드,매트랩,인기,프로그래밍,언어,랭킹,티,지수,순위',
#  '두산,디지털,이노베이션,사이버,보안,포럼',
#  '소상,공인,앱,우리,가게,패키지,챗,탑재',
#  '한국,레노버,아이디어,패드,세대,신제품,출시',
#  '기,정기,컴퍼니,도약,것',
#  '파일럿,탑재,프리뷰,공개,협업,효율,개선,방점',
#  '브이,네이버,커머스,솔루션,마켓,입점',
#  '바스,위지윅,스튜디오,메라,음성,지능,디지털,트윈,업무,협약,체결',
#  '인치,생산,능력,최고,경신',
#  '패러다임,도래,책임,등,외부,변화,직면,테크',
#  '올리브,네트웍,마켓,레이스,플렉스,정식,론칭',
#  '카카오,정기,총서,이사,보수,한도,정안,의결',
#  '블로그,클라우드,워싱,마케팅',
#  '플러그인,의미,의도,무엇',
#  '플러그인,의미,의도,무엇',
#  '빅펄,헤드,앱,기반,대화,뉴스,챗봇,도입',
#  '카카오,브레인,디스커버,프로필,서비스,출시',
#  '버넥트,이노,시뮬레이션,가상,훈련,기술,고도화,협력,체결',
#  '해외,특허분쟁,위험성,확인,가능,위험,경보,시스템,개통',
#  '국내,구진,이차전지,성능,획기,개선,초박,고분자,보호,개발',
#  '트위터,사용자,수백만,속인,유명인,합성,사진,전문가,경고,사실,거짓,구분',
#  '코딩,트렌드,인기,프로그래밍,언어,랭킹,티,지수,순위',
#  '시대,견인,표준,등장',
#  '콘텐츠,연관,산업,해외,판로,개척,역할,톡톡',
#  '아이폰,프랑스,일부,국가,카드,레이,제거,가능성,제기',
#  '팀뷰어,텐서,노스,페이,무인,결제,기기,실시간,원격지원',
#  '서비스,춘추전국,도래,앱,차별,강조',
#  '삼성,반도체,전문,인재,울산,대구,광주,과기원',
#  '마이크로,닉스,지포스,화이트,에디,출시',
#  '인텔,프로,미니,신제품,출시',
#  '텐센트,바이두,엔비디아,쿠다,채택',
#  '무하,서류,평가,서비스,프리즘,제공',
#  '티맥스,티베로,오피스,정통부,주최,프리,마켓,페어,참가',
#  '테스,코리아,봄맞이,제품,구매,인증,이벤트,진행',
#  '그룹,충남,아산,토리,사업,황산니켈,공장,준공',
#  '넥스,세계,보안,엑스포,알고리즘,기반,신제품,공개',
#  '현대,인프라,코어,사명,두산',
#  '검색,대신,채팅,빙챗,성공,위협,구글',
#  '큐어,코딩,보안,이슈,코드',
#  '큐어,코딩,보안,이슈,코드',
#  '한화,시스템,맞춤,교육,취업,지원,솔루션,특허,획득',
#  '개발자,이내,전망',
#  '트위터,소스,코드,깃허브,유출',
#  '구글,챗봇,바드,좌익,성향,영국,정치,편향,논란',
#  '인텔,세대,코어,기반,프로,플랫폼,발표',
#  '널리,소프트,개인,사업자,세금,신고,지원,세,계산기,탑재',
#  '제안,양자,인터넷,기술,국제,표준화,과제,승인',
#  '스패,로우,이노룰스,소스코드,점검,공급',
#  '코딩,트렌드,인기,프로그래밍,언어,랭킹,티,지수,순위',
#  '지멘스,모바일,드라이브,디지털,트윈,제공,자율,주행,구축,지원',
#  '블룸버그,기자,애플,워치,혈당,모니터링,기술,출시,최대',
#  '윤경,대표이사,후보,전격,사퇴',
#  '투입,부문,개발,검증,사업,본격',
#  '오라클,엔비디아,서비스,공급',
#  '스핀,글로벌,퀸텟,시스,템즈,기반,앱,서비스,사업,추진,업무,협약,체결',
#  '한국,레노버,씽크패드,시리즈,신제품,출시',
#  '아이,디스,자체,개발,러닝,엔진,기반,수술실,세이프,솔루션,출시',
#  '블로그,알리,공론,멀티,클라우드,거짓말,가지',
#  ...]

# %%
df_bloter['total_keywords'] = t_keyword_list
df_bloter['total_keywords']
# Out:
# 0                 대시보드,모니터링,미래,스택,옵저버
# 1                 베,선정,올해,프로그래밍,언어,비밀
# 2            글로벌,칼럼,비즈니스,환경,윈도우,그늘,방법
# 3                         직원,회사,가지,이유
# 4       엔비디아,반도체,기업,최초,달러,전쟁,무기,판매,업체
#                     ...
# 6636          그룹,개사,종로타워,터전,그린,캠퍼스,출범
# 6637         앤듀로샛,로켓,관측,엣지,컴퓨팅,시스템,공급
# 6638               노르딕,브레이브,리지,플랫폼,공급
# 6639           정통부,디지털,트윈,실증,사업,본격,착수
# 6640                 타입,스크립트,출시,노드,지원
# Name: total_keywords, Length: 6641, dtype: object

# %% [markdown]
# ### 'news_key', 'news_text_key' 컬럼 삭제

# %%
df_bloter.drop(['news_key', 'news_txt_key'], axis=1, inplace=True)

# %% [markdown]
# ### news_date를 datetime으로

# %%
# df_techworld
df_bloter['news_date'] = df_bloter['news_date'].str.replace(r' ', '-', regex=True)
# df_total['news_date']

# %% [markdown]
# ## totalnews_k_t.csv 파일에 반영

# %%
df_bloter.to_csv("../data_crawling_D/after_keywords/totalnews_k_t.csv", mode='w')

# %% [markdown]
# # 2. 신뢰도 평가 : news_titlw, news_text_sm의 데이터를 KRWORDRANK로 추출

# %%
import pandas as pd
import numpy as np

# %%
# 먼저 news_text_sm 컬럼의 값들을 뭉쳐서 하나의 string(각 요소는 '\n'로 나누기)
# 으로 통합
import csv # sql_cwn_data에서 갖고 오기

f = open("../data_crawling_D/after_keywords/totalnews_k_t.csv", "r", encoding='utf8')
reader = csv.reader(f)
next(reader)
# print(reader)
data = []
for row in reader:
    data.append(row)
    # print(row)
f.close()

# %%
# data

# %%
# dataframe으로 만들기
df_bloter = pd.DataFrame(data=data, columns=['idx','news_date', 'news_title', 'news_text_sm', 'url_in', 'news_writer', 'tags_string', 'thumb_addr', 'news_site', 'total_keywords'])  
# idx (인덱스) 제거
df_bloter = df_bloter[['news_date', 'news_title', 'news_text_sm', 'url_in', 'news_writer', 'tags_string', 'thumb_addr', 'news_site','total_keywords']]
df_bloter
# Out:
#              news_date                                     news_title  \
# 0          2023-05-31-                대시보드로 보는 모니터링의 미래, '풀스택 옵저버빌리티'
# 1          2023-05-31-                      티오베 선정 ‘올해의 프로그래밍 언어’의 비밀
# 2           2023-05-31          글로벌 칼럼 | 맥이 비즈니스 환경에서 윈도우의 그늘을 벗어난 방법
# 3           2023-05-31                         IT 직원이 회사를 떠나는 12가지 이유
# 4           2023-05-31  엔비디아, 반도체기업 최초 시총 1조 달러 “AI 전쟁터의 유일한 무기 판매업체”
# ...                ...                                            ...
# 6636  2022-05-31-10:36                   SK그룹 6개사 종로타워에 새 터전 그린캠퍼스 출범
# 6637  2022-05-31-10:12                  IBM 앤듀로샛 로켓에 관측용 엣지컴퓨팅 시스템 공급
# 6638  2022-05-31-09:48             노르딕 브레이브리지 IoT 플랫폼에 nRF9160 SiP 공급
# 6639  2022-05-31-08:49                     과기정통부 디지털트윈(DW) 실증사업 본격 착수
# 6640        2022-05-31               타입스크립트 4.7 출시…“노드.js 16용 ESM 지원”
#
#                                            news_text_sm  \
# 0     IT 성능 관리를 위해 도입하던 ‘모니터링’이 한계에 달했다는 평가와 더불어, ‘옵...
# 1     좋은 프로그래밍 언어는 어떻게 정의할 수 있을까요? 상황에 따라 중요도는 다르겠지만...
# 2     2006년 1월, 애플은 비즈니스 세계에서 성공을 향한 중요한 발걸음을 내디뎠다. ...
# 3     IT 인력에 대한 수요가 증가한다. 인력 시장이 여전히 경색되어 있다. CIO로서는...
# 4     AI와 관련한 핵심 투자처를 물색하던 투자자들이 기반을 찾은 것으로 보인다. 30일...
# ...                                                 ...
# 6636  SK그룹에서 친환경 사업을 담당하는 관계사가 서울 종로구에 마련된 ‘그린캠퍼스’에 ...
# 6637  IBM이 최근 엔듀로샛이 발사한 우주로켓에 IBM의 오픈소스 하이브리드클라우드 인공...
# 6638  노르딕세미컨덕터가 일본 IoT 솔루션 기업인 브레이브리지(Braveridge)의 I...
# 6639  과학기술정보통신부가 한국지능정보사회진흥원(NIA) 정보통신산업진흥원(NIPA)과 함...
# 6640  ‘타입스크립트 4.7(TypeScript 4.7)’이 프로덕션 릴리즈로 출시됐다. ...
#
#                                                  url_in       news_writer  \
# 0        https://yozm.wishket.com/magazine/detail/2047/               조은정
# 1        https://yozm.wishket.com/magazine/detail/2046/               애옹킴
# 2     https://www.itworld.co.kr/t/55049/%EA%B8%80%EB...   Anirban Ghoshal
# 3     https://www.itworld.co.kr/t/55049/%EA%B8%80%EB...        Paul Krill
# 4     https://www.itworld.co.kr/t/55049/%EA%B8%80%EB...     Neal Weinberg
# ...                                                 ...               ...
# 6636  https://www.itbiznews.com//news/articleView.ht...               박인환
# 6637  https://www.itbiznews.com//news/articleView.ht...               오현식
# 6638  https://www.itbiznews.com//news/articleView.ht...               최태우
# 6639  https://www.itbiznews.com//news/articleView.ht...               김소현
# 6640  https://www.itworld.co.kr/t/61023/%EA%B0%9C%EB...  Anirban Ghoshal?
#
#                                           tags_string  \
# 0
# 1
# 2
# 3
# 4
# ...                                               ...
# 6636                          #친환경,#탄소중립,#그린캠퍼스,#SK그룹
# 6637                            #앤듀로샛,#IBM,#우주,#우주 산업
# 6638  #산업용 IoT,#IIoT,#시스템인패키지,#SiP,#nRF9160,#노르딕세미컨덕터
# 6639        #디지털트윈,#DW,#시뮬레이션,#탄소저감,#실증사업,#NIA,#과기정통부
# 6640
#
#                                              thumb_addr news_site  \
# 0      https://yozm.wishket.com/media/news/2047/imag...      요즘IT
# 1     https://yozm.wishket.com/media/news/2046/image...      요즘IT
# 2     https://www.itworld.co.kr/files/itworld/ITW202...   ITWorld
# 3     https://www.itworld.co.kr/files/ciokr/2023/05/...   ITWorld
# 4     https://www.itworld.co.kr/files/itworld/ITW202...   ITWorld
# ...                                                 ...       ...
# 6636  https://www.cwn.kr./thumbnail/202205/72853_674...     ITBiz
# 6637  https://www.cwn.kr./thumbnail/202205/72831_674...     ITBiz
# 6638  https://www.cwn.kr./thumbnail/202205/72852_674...     ITBiz
# 6639  https://www.cwn.kr./thumbnail/202205/72849_674...     ITBiz
# 6640  https://www.itworld.co.kr/files/ciokr/2022/05/...   ITWorld
#
#                      total_keywords
# 0               대시보드,모니터링,미래,스택,옵저버
# 1               베,선정,올해,프로그래밍,언어,비밀
# 2          글로벌,칼럼,비즈니스,환경,윈도우,그늘,방법
# 3                       직원,회사,가지,이유
# 4     엔비디아,반도체,기업,최초,달러,전쟁,무기,판매,업체
# ...                             ...
# 6636        그룹,개사,종로타워,터전,그린,캠퍼스,출범
# 6637       앤듀로샛,로켓,관측,엣지,컴퓨팅,시스템,공급
# 6638             노르딕,브레이브,리지,플랫폼,공급
# 6639         정통부,디지털,트윈,실증,사업,본격,착수
# 6640               타입,스크립트,출시,노드,지원
#
# [6641 rows x 9 columns]

# %% [markdown]
# ## news_title과 news_text_sm를 합친 컬럼 생성하기

# %%
df_bloter['title_n_text'] = df_bloter[['news_title', 'news_text_sm']].apply(','.join, axis=1)
# df_techworld['title_n_text']

# %%
# 제목과 내용을 합친 str 컬럼을 news_date와 같이 엮어 df화
df_bloter_dnt = df_bloter[['news_date', 'title_n_text']]
# csv 파일로 저장하기
df_bloter_dnt.to_csv("../data_analysis_test/test_data/total_dnt.txt", mode='w', header=False, index=False, sep='\t')

# %%
# df_cwn_date = df_cwn['news_date'].to_list()
# df_cwn_text = df_cwn['news_text_sm'].to_list()
# df_cwn_date_n_text = {}
# for date, text in zip(df_cwn_date, df_cwn_text):
#     df_cwn_date_n_text[date] = text
                          
# print('dict zip : ', df_cwn_date_n_text)

# df_cwn_text

# %%
df_bloter_dnt
# Out:
#              news_date                                       title_n_text
# 0          2023-05-31-  대시보드로 보는 모니터링의 미래, '풀스택 옵저버빌리티',IT 성능 관리를 위해 도...
# 1          2023-05-31-  티오베 선정 ‘올해의 프로그래밍 언어’의 비밀,좋은 프로그래밍 언어는 어떻게 정의할...
# 2           2023-05-31  글로벌 칼럼 | 맥이 비즈니스 환경에서 윈도우의 그늘을 벗어난 방법,2006년 1월...
# 3           2023-05-31  IT 직원이 회사를 떠나는 12가지 이유,IT 인력에 대한 수요가 증가한다. 인력 ...
# 4           2023-05-31  엔비디아, 반도체기업 최초 시총 1조 달러 “AI 전쟁터의 유일한 무기 판매업체”,...
# ...                ...                                                ...
# 6636  2022-05-31-10:36  SK그룹 6개사 종로타워에 새 터전 그린캠퍼스 출범,SK그룹에서 친환경 사업을 담당...
# 6637  2022-05-31-10:12  IBM 앤듀로샛 로켓에 관측용 엣지컴퓨팅 시스템 공급,IBM이 최근 엔듀로샛이 발사...
# 6638  2022-05-31-09:48  노르딕 브레이브리지 IoT 플랫폼에 nRF9160 SiP 공급,노르딕세미컨덕터가 일...
# 6639  2022-05-31-08:49  과기정통부 디지털트윈(DW) 실증사업 본격 착수,과학기술정보통신부가 한국지능정보사회...
# 6640        2022-05-31  타입스크립트 4.7 출시…“노드.js 16용 ESM 지원”,‘타입스크립트 4.7(T...
#
# [6641 rows x 2 columns]

# %%
# f = open("../know_arc_pjt/data_crawling_D/data_sql_total_edited/total_news_t_202306221233.csv", "r", encoding='utf8')
# reader = csv.reader(f)

# for row in reader:
#     data = list(reader)
# # print(data)
# f.close()
# # dataframe으로 만들기
# df_total_t = pd.DataFrame(data=data, columns=['news_date', 'news_title', 'news_text_sm', 'url_in', 'news_writer', 'tags_string', 'thumb_addr', 'news_site'])  
# df_total_t

# %%
# 날짜당 제목에서 추출한 키워드 목록
def get_date_text(fname):
    # 튜토리얼에서 이용하는 `fname` 파일은 영화평과 평점이 \t 으로 구분된 two column tsv 파일입니다.
    # 예시는 이 cell 의 output 을 참고하세요.
    with open(fname, encoding='utf-8') as f:
        docs = [doc.lower().replace('\n','').split('\t') for doc in f] 
        docs = [doc for doc in docs if len(doc) == 2]

        if not docs:
            return [], []
        
        dates, texts = zip(*docs)
        return dates, texts

# cwn.kr data (df_cwn_date_n_text)
fname = '../data_analysis_test/test_data/total_dnt.txt'
# 이걸로 
dates, texts = get_date_text(fname)
# dates = list(dates)
# texts = list(texts)
# 위쪽의 5개 출력하기
# with open(fname, encoding="utf-8") as f:
#     for _ in range(5):
#         print(next(f).strip())

# %%
# dates
# texts

# %%
# KR-WordRank에 필요한 라이브러리
import sys
import re
sys.path.append('../')
from krwordrank.word import KRWordRank
from krwordrank.hangle import normalize
import krwordrank
# print(krwordrank.__version__)

# %% [markdown]
# 단어 추출에 영어/숫자를 포함할 예정이라면 normalize함수를 이용하여 텍스트를 normalize할 것

# %%
with open('../data_analysis_test/test_data/total_dnt_norm.txt', 'w', encoding='utf-8') as f:
    for date, text in zip(dates, texts):
        text = normalize(text, english=True, number=True)
        # 특수문자는 제거
        text = re.sub(r"[^\uAC00-\uD7A30-9a-zA-Z\s]", "", text)
        f.write('%s\t%s\n' % (date, text))

# %% [markdown]
# ## 해당 데이터에서 핵심 키워드들을 뽑아보자

# %%
# df_cwn_date_n_text
fname = '../data_analysis_test/test_data/total_dnt_norm.txt'
dates_n, texts_n = get_date_text(fname)
# 여기까진 dates_n, texts_n이 서로 분리되어있음

# %%
wordrank_extractor = KRWordRank(
    min_count = 5, # 단어의 최소 출현 빈도수 (그래프 생성 시)
    max_length = 10, # 단어의 최대 길이
    verbose = True
    )

beta = 0.85    # PageRank의 decaying factor beta
max_iter = 10

# 여기서 for문
# text_key_list = []
# for text in texts_n:
keywords, rank, graph = wordrank_extractor.extract(texts_n, beta, max_iter)
# Out:
# scan vocabs ...
# num vocabs = 65337
# done = 10 Early stopped.

# %%
# keywords

# %% [markdown]
# 위와 같이 vocabulary를 미리 설정하거나 decaying factor를 단어별로 다르게 (bias) 할당할 수 있으며, 모든 단어의 랭킹의 총 합은 vocabulary size와 같음. 즉 default decaying factor는 1.0

# %%
# 불용어 파일 읽기
stop_words = []
with open('../data_analysis_test/불용.txt', 'r', encoding='utf-8') as file:
   stop_words = file.read().splitlines()
# keyword_list
    
# # 불용어 제거
pop_list = []
for keyword in keywords:
    # print(keyword)
    # print(type(keyword))
    if keyword in stop_words:
        pop_list.append(keyword)
        # print(keyword)
        
# print(pop_list)
for p in pop_list:
    # print(p)
    keywords.pop(p, None)

# # filtered_tokens =  [token for token in keyword_list[0] if token not in stop_words]
# # filtered_tokens
# keywords

# %%
top_keywords = []
# for word, r in sorted(keywords.items(), key=lambda x:x[1], reverse=True)[:30]:
#     print('%8s:\t%.4f' % (word, r))
top_keywords.append(
    sorted(keywords.items(),
           key=lambda x:x[1],
           reverse=True)[:100]
)


keyword_list = []
for keywords in top_keywords:
    words, ranks = zip(*keywords)
    print(words)
    
    keyword_list.append(words)
# Out:
# ('ai', '개발', '데이터', '기업', '언어', '프로', '서비스', '플랫폼', '보안', '디지털', '지원', '솔루션', '시장', '글로벌', '코딩', '클라', '출시', '사업', '전문', '구글', '분석', '기능', '애플', '시스템', '코드', '국내', '메타', 'nft', '공개', '한편', '순위', '연구', '운영', '제품', '매체', 'tiobe', '구축', '기존', '교육', '스마트', '정보', '고객', '사이버', '투자', '발표', '지수', '테크', '산업', '분야', '출처', '소프트', '인기', '학습', 'it', '문제', '인공', '신규', '통합', '생성', '검색', '공식', '오픈', '콘텐츠', '가능', '이미', '티오베', '게임', '공급', '협력', '로봇', '이어', '체결', '모델', '한국', '진행', '자동', '증가', '가상', '이에', '업무', '비즈니스', 'pyp', '결과', '온라인', '환경', '네이버', '추가', '자바', '중국', 'in', '기준', '파이썬', '적용', '확장', '영상', '마이', '업계', '했다', 'language', '혁신')

# %%
for k in range(100):
    
    message = '  --  '.join(
        ['%8s (%.3f)' % (top_keywords[0][k][0],top_keywords[0][k][1])]
         )
    print(message)
# 여기까지가 기사 본문으로부터 키워드 추출
# Out:
#       ai (114.035)
#       개발 (93.242)
#      데이터 (82.400)
#       기업 (75.119)
#       언어 (74.538)
#       프로 (70.448)
#      서비스 (64.087)
#      플랫폼 (54.836)
#       보안 (51.525)
#      디지털 (44.608)
#       지원 (39.835)
#      솔루션 (37.091)
#       시장 (35.186)
#      글로벌 (33.151)
#       코딩 (32.463)
#       클라 (31.117)
#       출시 (29.688)
#       사업 (29.684)
#       전문 (29.500)
#       구글 (29.211)
#       분석 (28.810)
#       기능 (28.048)
#       애플 (26.449)
#      시스템 (25.817)
#       코드 (25.629)
#       국내 (25.307)
#       메타 (25.016)
#      nft (24.971)
#       공개 (24.901)
#       한편 (24.523)
#       순위 (23.793)
#       연구 (23.679)
#       운영 (22.637)
#       제품 (22.443)
#       매체 (22.399)
#    tiobe (22.059)
#       구축 (21.982)
#       기존 (21.902)
#       교육 (21.879)
#      스마트 (21.842)
#       정보 (21.689)
#       고객 (21.573)
#      사이버 (21.470)
#       투자 (21.315)
#       발표 (21.006)
#       지수 (20.768)
#       테크 (20.305)
#       산업 (20.277)
#       분야 (20.065)
#       출처 (19.972)
#      소프트 (19.814)
#       인기 (19.777)
#       학습 (19.627)
#       it (19.189)
#       문제 (19.000)
#       인공 (18.906)
#       신규 (18.561)
#       통합 (18.446)
#       생성 (18.441)
#       검색 (18.043)
#       공식 (17.819)
#       오픈 (17.782)
#      콘텐츠 (17.721)
#       가능 (17.499)
#       이미 (17.158)
#      티오베 (16.958)
#       게임 (16.712)
#       공급 (16.699)
#       협력 (16.689)
#       로봇 (16.682)
#       이어 (16.644)
#       체결 (16.633)
#       모델 (16.551)
#       한국 (16.426)
#       진행 (16.370)
#       자동 (16.258)
#       증가 (16.240)
#       가상 (16.015)
#       이에 (15.804)
#       업무 (15.614)
#     비즈니스 (15.574)
#      pyp (15.409)
#       결과 (15.407)
#      온라인 (15.394)
#       환경 (15.240)
#      네이버 (15.134)
#       추가 (15.128)
#       자바 (14.813)
#       중국 (14.774)
#       in (14.625)
#       기준 (14.400)
#      파이썬 (14.377)
#       적용 (14.012)
#       확장 (13.891)
#       영상 (13.845)
#       마이 (13.738)
#       업계 (13.699)
#       했다 (13.597)
# language (13.499)
#       혁신 (13.468)

# %% [markdown]
#  top 100에서 중복되는 키워드들을 제거하고 차이가 있는 키워드만 추출해서 살펴보겠습니다.

# %%
keyword_counter = {}

w_l = []
r_l = []
for keywords in top_keywords:
    words, ranks = zip(*keywords)
    for word in words:
        keyword_counter[word] = keyword_counter.get(word, 0) + 1
        w_l.append(word)
    for rank in ranks:
        r_l.append(rank)

csv_list = list(zip(w_l, r_l))
common_keywords = {word for word, count in keyword_counter.items() if count == 3}
len(common_keywords)
# Out:
# 0

# %%
# csv_list

# %%
df_csv = pd.DataFrame(data=csv_list, columns=['words','ranks'])
df_csv = df_csv.sort_values(by=['ranks'], ascending=False)
df_csv
# Out:
#        words       ranks
# 0         ai  114.034656
# 1         개발   93.241920
# 2        데이터   82.399764
# 3         기업   75.119100
# 4         언어   74.537960
# ..       ...         ...
# 95        마이   13.738497
# 96        업계   13.699191
# 97        했다   13.597185
# 98  language   13.498563
# 99        혁신   13.468302
#
# [100 rows x 2 columns]

# %%
df_csv.to_csv("../data_crawling_D/keywords/total_keywords.csv", mode='w')

# %%
# 프로그래밍 워드클라우드 용 랭킹
print(df_csv.loc[df_csv['words'] == '언어'])
df_csv_lang = df_csv.drop(df_csv.index[0:3], axis=0)
# df_csv_lang
df_csv_lang.to_csv("../data_crawling_D/keywords/total_keywords_lang.csv", mode='w')
# Out:
#   words     ranks
# 4    언어  74.53796

# %%
# 트렌드 워드클라우드 용 랭킹
print(df_csv.loc[df_csv['words'] == '인기'])
df_csv_pop = df_csv.drop(df_csv.index[0:50], axis=0)
# df_csv_pop
df_csv_pop.to_csv("../data_crawling_D/keywords/total_keywords_pop.csv", mode='w')
# Out:
#    words      ranks
# 51    인기  19.777267

# %%
# 코드 워드클라우드 용 랭킹
print(df_csv.loc[df_csv['words'] == '데이터'])
df_csv_code = df_csv.drop(df_csv.index[0:1], axis=0)
# df_csv_code
df_csv_code.to_csv("../data_crawling_D/keywords/total_keywords_code.csv", mode='w')
# Out:
#   words      ranks
# 2   데이터  82.399764

# %% [markdown]
# ## 키워드 분석

# %% [markdown]
# ## # Reference keywords

# %%
# df_techworld
df_techworld_tnt = df_techworld[['news_date', 'total_keywords']]
# df_techworld_tnt

# %%
# 데이터프레임에서 '내용'과 '작성일' 열을 가져옴
import re
from collections import Counter

# 모듈화하기
def get_keyword_monthly_agg(df_techworld_tnt):
    text_data = df_techworld_tnt['total_keywords']
    date_data = df_techworld_tnt['news_date']
    
    
    # 단어 등장 횟수를 저장할 딕셔너리 초기화
    word_counts = {}
    # 월별 단어 집계
    word_n_cnt_list = []
    
    # 데이터프레임을 순회하며 월 별로 단어 등장 횟수 집계
    for text, date in zip(text_data, date_data):
        # 텍스트 토큰화 및 형태소 분석
        
        # 년 추출
        tokens = text.split(",")
        year = date.split('-')[0]
        # 월 추출
        month = date.split('-')[1]
        year_month = year + '-' + month

        # 단어 등장 횟수 집계
        if year_month in word_counts:
            for token in tokens:
                word_counts[year_month][token] = word_counts[year_month].get(token, 0) + 1
        else:
            word_counts[year_month] = {}
            for token in tokens:
                word_counts[year_month][token] = 1
                
    # 횟수가 2이상인 단어만 추출하기
    min_word_count = 2
    top_words_limit = 21 # 최대 20개
    
    # 월 별로 상위 단어 추출
    
    for year_month, counts in word_counts.items():
        # print(f"{month}월")
        # 횟수만 추출하기
        sorted_counts = sorted(counts.items(), key=lambda x: x[1], reverse=True)
        
        # 횟수가 2이상인 단어 필터링
        filtered_counts = [(word, count) for word, count in sorted_counts if count >= min_word_count]
        
        # 만약 2이상인 단어의 수가 5개 미만이면 모든 단어 추출
        if len(filtered_counts) < top_words_limit:
            filtered_counts = sorted_counts
        # 상위 단어 출력
        top_words = filtered_counts[:top_words_limit]
        for word, count in top_words:
            # print(f" {word} | 등장횟수: {count}")
            word_n_cnt_list.append([year_month, word, count])
        # print(word_n_cnt_list)
        print()
    
    return word_n_cnt_list

tw_key_list = get_keyword_monthly_agg(df_techworld_tnt)
# df_tw_key_h_list

# %%
# 리스트를 df으로
df_tw_key_list = pd.DataFrame(tw_key_list, columns=['date','words','cnt'])
print('2차원 리스트로 만든 dataframe:\n', df_tw_key_list)
# Out:
# 2차원 리스트로 만든 dataframe:
#          date words  cnt
# 0    2023-05  클라우드   34
# 1    2023-05    출시   20
# 2    2023-05    기반   18
# 3    2023-05   글로벌   18
# 4    2023-05   솔루션   16
# ..       ...   ...  ...
# 247  2022-06    테크   26
# 248  2022-06   데이터   26
# 249  2022-06   파트너   24
# 250  2022-06    지원   22
# 251  2022-06    지능   22
#
# [252 rows x 3 columns]

# %%
# pivot으로 {인덱스 : date, 컬럼: words, 값: cnt}인 테이블 생성
df_tw_key_pivot = df_tw_key_list.pivot(index='date', columns='words', values='cnt')
df_tw_key_pivot.fillna('0', inplace=True) # 결측값 0처리
df_tw_key_pivot = df_tw_key_pivot.apply(pd.to_numeric)
# df_tw_key_pivot

# %%
df_tw_key_pivot.info()

# %%
# 각 단어당 cnt 합산을 구한 뒤 상위 100개 리스트에 담기
df_tw_key_pivot_sum = df_tw_key_pivot.sum()
df_tw_key_pivot_sum_srt = df_tw_key_pivot_sum.sort_values(ascending=False)
df_tw_key_pivot_sum_srt
# Out:
# words
# 클라우드      452.0
# 출시        362.0
# 솔루션       349.0
# 서비스       300.0
# 사업        263.0
#           ...
# 공략          6.0
# 공공          6.0
# 이스트소프트      6.0
# 유공          6.0
# 티맥스소프트      6.0
# Length: 65, dtype: float64

# %%
# 인덱스에서 word를 빼내고
df_tw_key_pivot_sum_srt = df_tw_key_pivot_sum_srt.reset_index(drop=False)

# %%
ref_key_list = df_tw_key_pivot_sum_srt['words'].to_list()
# ref_list

# %%
# 100개 reference용 키워드 추출
top_100_ref_list = ref_key_list[:100]

# %%
top_100_kw_list = []
for k in range(100):
    # print(top_keywords[0][k][0])
    top_100_kw_list.append(top_keywords[0][k][0])
print(top_100_kw_list)
# Out:
# ['ai', '클라우드', '기업', '서비스', '솔루션', '데이터', '플랫폼', '디지털', '보안', '개발', '글로벌', '출시', '사업', '국내', '전문', '체결', '시장', '지원', '선정', '프로', '구축', '고객', '관리', '시스템', '업무', '발표', '운영', '한국', 'it', '제품', '산업', '메타', '대표', '서울', '비즈니스', '인공', '진행', '분석', '개최', '소프트', '인증', '파트너', '공급', '스마트', '분야', '연구', '로봇', '혁신', '통합', '스타트업', '협력', '자사', '기능', '투자', '올해', '공개', '교육', '환경', '자동', '획득', '인프라', '정보', '기존', '공공', '콘텐츠', '확대', '강화', '온라인', '오픈', '금융', '코리아', '구글', '확장', '영상', '모델', '3d', '추진', 'kt', '참가', 'mo', 'nft', '차세대', '6월', '성장', '가상', '신규', '인텔', '적용', '오라클', '마이', '가능', '가트너', '버추얼', '애플리케이션', 'digital', '의료', '공식', '매출', 'software', 'aws']

# %% [markdown]
# ## ROUGE-1,2,l 로 성능 평가

# %%
from rouge import Rouge

# 모델로 구한 키워드들
rank_list = top_100_kw_list
rank_str = " ".join(rank_list)
# 실제 헤드라인과 내용에서 집계한 키워드들
ref_str = " ".join(top_100_ref_list)
model_out = [rank_str]
# '다양한', '관련', '것이', '새로운', '최근', '분석', '출처:', '활용', '따라', '한다.', '세계', '공동', '가장', '하는', '현재', '기존', '등을', '점유율은', '모든', '다른', '대해', '많은', '순위', '결과를', '또한', '대비', '10', '신규', '이용', '이를', '주요', '모두', '문제', '그러나', '여러', '출시', '이미', '생성', '가능', '이어', '공개', '발표', '이후', '최신', '전했다', '특히', '이상', '인기', '이는', '하지만', '지수', '이러한', '때문에', '핵심', '6월', '아이', '것은', '그리고', '이에', '같이', '동시에', '각각', '참여', '시간', '전체', '하나', '수준', '물론', '다수', '동안', '9월', '어떤', '전망', '혹은', '양자', '전자', '바로', '여전히'
reference = [ref_str]
rouge = Rouge()
rouge.get_scores(model_out, reference, avg=True)

# >>>
# {   'rouge-1': {   'f': 0.6279006234427593,
#                    'p': 0.8604497354497355,
#                    'r': 0.5273531655225019},
#     'rouge-2': {   'f': 0.3883256484545606,
#                    'p': 0.5244559362206421,
#                    'r': 0.32954545454545453},
#     'rouge-l': {   'f': 0.6282785202429159,
#                    'p': 0.8122895622895623,
#                    'r': 0.5369305616983636}}
# Out:
# {'rouge-1': {'r': 0.6307692307692307, 'p': 0.41, 'f': 0.4969696921946741},
#  'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0},
#  'rouge-l': {'r': 0.2153846153846154, 'p': 0.14, 'f': 0.16969696492194689}}
